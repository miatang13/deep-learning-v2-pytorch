# %% [markdown]
# # Sentiment Classification & How To "Frame Problems" for a Neural Network
#
# by Andrew Trask
#
# - **Twitter**: @iamtrask
# - **Blog**: http://iamtrask.github.io

# %% [markdown]
# ### What You Should Already Know
#
# - neural networks, forward and back-propagation
# - stochastic gradient descent
# - mean squared error
# - and train/test splits
#
# ### Where to Get Help if You Need it
# - Re-watch previous Udacity Lectures
# - Leverage the recommended Course Reading Material - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) (Check inside your classroom for a discount code)
# - Shoot me a tweet @iamtrask
#
#
# ### Tutorial Outline:
#
# - Intro: The Importance of "Framing a Problem" (this lesson)
#
# - [Curate a Dataset](#lesson_1)
# - [Developing a "Predictive Theory"](#lesson_2)
# - [**PROJECT 1**: Quick Theory Validation](#project_1)
#
#
# - [Transforming Text to Numbers](#lesson_3)
# - [**PROJECT 2**: Creating the Input/Output Data](#project_2)
#
#
# - Putting it all together in a Neural Network (video only - nothing in notebook)
# - [**PROJECT 3**: Building our Neural Network](#project_3)
#
#
# - [Understanding Neural Noise](#lesson_4)
# - [**PROJECT 4**: Making Learning Faster by Reducing Noise](#project_4)
#
#
# - [Analyzing Inefficiencies in our Network](#lesson_5)
# - [**PROJECT 5**: Making our Network Train and Run Faster](#project_5)
#
#
# - [Further Noise Reduction](#lesson_6)
# - [**PROJECT 6**: Reducing Noise by Strategically Reducing the Vocabulary](#project_6)
#
#
# - [Analysis: What's going on in the weights?](#lesson_7)

# %% [markdown]
# # Lesson: Curate a Dataset<a id='lesson_1'></a>
# The cells from here until Project 1 include code Andrew shows in the videos leading up to mini project 1. We've included them so you can run the code along with the videos without having to type in everything.

# %%
def pretty_print_review_and_label(i):
    print(labels[i] + "\t:\t" + reviews[i][:80] + "...")

g = open('reviews.txt','r') # What we know!
reviews = list(map(lambda x:x[:-1],g.readlines()))
g.close()

g = open('labels.txt','r') # What we WANT to know!
labels = list(map(lambda x:x[:-1].upper(),g.readlines()))
g.close()

# %% [markdown]
# **Note:** The data in `reviews.txt` we're using has already been preprocessed a bit and contains only lower case characters. If we were working from raw data, where we didn't know it was all lower case, we would want to add a step here to convert it. That's so we treat different variations of the same word, like `The`, `the`, and `THE`, all the same way.

# %%
len(reviews)
# Out:
# 25000

# %%
reviews[0]
# Out:
# 'bromwell high is a cartoon comedy . it ran at the same time as some other programs about school life  such as  teachers  . my   years in the teaching profession lead me to believe that bromwell high  s satire is much closer to reality than is  teachers  . the scramble to survive financially  the insightful students who can see right through their pathetic teachers  pomp  the pettiness of the whole situation  all remind me of the schools i knew and their students . when i saw the episode in which a student repeatedly tried to burn down the school  i immediately recalled . . . . . . . . . at . . . . . . . . . . high . a classic line inspector i  m here to sack one of your teachers . student welcome to bromwell high . i expect that many adults of my age think that bromwell high is far fetched . what a pity that it isn  t   '

# %%
labels[0]
# Out:
# 'POSITIVE'

# %% [markdown]
# # Lesson: Develop a Predictive Theory<a id='lesson_2'></a>

# %%
print("labels.txt \t : \t reviews.txt\n")
pretty_print_review_and_label(2137)
pretty_print_review_and_label(12816)
pretty_print_review_and_label(6267)
pretty_print_review_and_label(21934)
pretty_print_review_and_label(5297)
pretty_print_review_and_label(4998)
# Out:
# labels.txt 	 : 	 reviews.txt
#
# NEGATIVE	:	this movie is terrible but it has some good effects .  ...
# POSITIVE	:	adrian pasdar is excellent is this film . he makes a fascinating woman .  ...
# NEGATIVE	:	comment this movie is impossible . is terrible  very improbable  bad interpretat...
# POSITIVE	:	excellent episode movie ala pulp fiction .  days   suicides . it doesnt get more...
# NEGATIVE	:	if you haven  t seen this  it  s terrible . it is pure trash . i saw this about ...
# POSITIVE	:	this schiffer guy is a real genius  the movie is of excellent quality and both e...

# %% [markdown]
# # Project 1: Quick Theory Validation<a id='project_1'></a>
#
# There are multiple ways to implement these projects, but in order to get your code closer to what Andrew shows in his solutions, we've provided some hints and starter code throughout this notebook.
#
# You'll find the [Counter](https://docs.python.org/2/library/collections.html#collections.Counter) class to be useful in this exercise, as well as the [numpy](https://docs.scipy.org/doc/numpy/reference/) library.

# %%
from collections import Counter
import numpy as np

# %% [markdown]
# We'll create three `Counter` objects, one for words from postive reviews, one for words from negative reviews, and one for all the words.

# %%
# Create three Counter objects to store positive, negative and total counts
positive_counts = Counter()
negative_counts = Counter()
total_counts = Counter()

# %% [markdown]
# **TODO:** Examine all the reviews. For each word in a positive review, increase the count for that word in both your positive counter and the total words counter; likewise, for each word in a negative review, increase the count for that word in both your negative counter and the total words counter.
#
# **Note:** Throughout these projects, you should use `split(' ')` to divide a piece of text (such as a review) into individual words. If you use `split()` instead, you'll get slightly different results than what the videos and solutions show.

# %%
# TODO: Loop over all the words in all the reviews and increment the counts in the appropriate counter objects
for i in range(len(reviews)):
    words = reviews[i].split(' ')
    for w_i in range(len(words)):
        if labels[i] == 'POSITIVE':
            positive_counts[words[w_i]] += 1
        else:
            negative_counts[words[w_i]] += 1
        total_counts[words[w_i]] += 1

# %% [markdown]
# Run the following two cells to list the words used in positive reviews and negative reviews, respectively, ordered from most to least commonly used.

# %%
# Examine the counts of the most common words in positive reviews
positive_counts.most_common()
# Out:
# [('', 2201872),
#  ('the', 1039944),
#  ('.', 957924),
#  ('and', 538332),
#  ('a', 502128),
#  ('of', 461130),
#  ('to', 400476),
#  ('is', 343470),
#  ('in', 301290),
#  ('br', 295410),
#  ('it', 288150),
#  ('i', 244458),
#  ('that', 213780),
#  ('this', 210480),
#  ('s', 202890),
#  ('as', 157848),
#  ('with', 139482),
#  ('for', 134496),
#  ('was', 131502),
#  ('film', 125622),
#  ('but', 124932),
#  ('movie', 114444),
#  ('his', 103362),
#  ('on', 102048),
#  ('you', 100086),
#  ('he', 97692),
#  ('are', 88842),
#  ('not', 85632),
#  ('t', 82320),
#  ('one', 81930),
#  ('have', 75522),
#  ('be', 74496),
#  ('by', 71982),
#  ('all', 71652),
#  ('who', 68784),
#  ('an', 67764),
#  ('at', 67404),
#  ('from', 64602),
#  ('her', 62844),
#  ('they', 59370),
#  ('has', 55116),
#  ('so', 54924),
#  ('like', 54228),
#  ('about', 49878),
#  ('very', 49830),
#  ('out', 48804),
#  ('there', 48342),
#  ('she', 46674),
#  ('what', 46422),
#  ('or', 46392),
#  ('good', 46320),
#  ('more', 45126),
#  ('when', 44736),
#  ('some', 44646),
#  ('if', 43710),
#  ('just', 42912),
#  ('can', 42006),
#  ('story', 40680),
#  ('time', 39090),
#  ('my', 38928),
#  ('great', 38514),
#  ('well', 38430),
#  ('up', 37926),
#  ('which', 37602),
#  ('their', 36642),
#  ('see', 36156),
#  ('also', 33300),
#  ('we', 33186),
#  ('really', 32856),
#  ('would', 32400),
#  ('will', 31308),
#  ('me', 31002),
#  ('had', 30888),
#  ('only', 30822),
#  ('him', 30108),
#  ('even', 29784),
#  ('most', 29184),
#  ('other', 29148),
#  ('were', 28692),
#  ('first', 28530),
#  ('than', 28416),
#  ('much', 28110),
#  ('its', 27732),
#  ('no', 27444),
#  ('into', 27264),
#  ('people', 26874),
#  ('best', 25914),
#  ('love', 25806),
#  ('get', 25632),
#  ('how', 25278),
#  ('life', 25194),
#  ('been', 25134),
#  ('because', 24474),
#  ('way', 24216),
#  ('do', 23646),
#  ('made', 22938),
#  ('films', 22878),
#  ('them', 22830),
#  ('after', 22800),
#  ('many', 22596),
#  ('two', 22398),
#  ('too', 21954),
#  ('think', 21930),
#  ('movies', 21516),
#  ('characters', 21360),
#  ('character', 21084),
#  ('don', 20808),
#  ('man', 20760),
#  ('show', 20592),
#  ('watch', 20544),
#  ('seen', 20484),
#  ('then', 20148),
#  ('little', 20046),
#  ('still', 20040),
#  ('make', 19818),
#  ('could', 19422),
#  ('never', 19356),
#  ('being', 19302),
#  ('where', 19038),
#  ('does', 18414),
#  ('over', 18102),
#  ('any', 18012),
#  ('while', 17394),
#  ('know', 16998),
#  ('did', 16740),
#  ('years', 16548),
#  ('here', 16440),
#  ('ever', 16404),
#  ('end', 16176),
#  ('these', 16164),
#  ('such', 15540),
#  ('real', 15408),
#  ('scene', 15402),
#  ('back', 15282),
#  ('those', 14910),
#  ('though', 14850),
#  ('off', 14778),
#  ('new', 14748),
#  ('your', 14718),
#  ('go', 14640),
#  ('acting', 14622),
#  ('plot', 14592),
#  ('world', 14574),
#  ('scenes', 14562),
#  ('say', 14484),
#  ('through', 14454),
#  ('makes', 14340),
#  ('better', 14286),
#  ('now', 14208),
#  ('work', 14076),
#  ('young', 14058),
#  ('old', 13866),
#  ('ve', 13842),
#  ('find', 13632),
#  ('both', 13488),
#  ('before', 13062),
#  ('us', 12972),
#  ('again', 12948),
#  ('series', 12918),
#  ('quite', 12858),
#  ('something', 12810),
#  ('cast', 12798),
#  ('should', 12726),
#  ('part', 12588),
#  ('always', 12528),
#  ('lot', 12522),
#  ('another', 12450),
#  ('actors', 12282),
#  ('director', 12240),
#  ('family', 12192),
#  ('own', 12096),
#  ('between', 12096),
#  ('m', 11988),
#  ('may', 11982),
#  ('same', 11832),
#  ('role', 11802),
#  ('watching', 11796),
#  ('every', 11724),
#  ('funny', 11718),
#  ('doesn', 11610),
#  ('performance', 11568),
#  ('few', 11508),
#  ('bad', 11442),
#  ('look', 11400),
#  ('re', 11304),
#  ('why', 11130),
#  ('things', 11094),
#  ('times', 10992),
#  ('big', 10890),
#  ('however', 10770),
#  ('actually', 10740),
#  ('action', 10734),
#  ('going', 10698),
#  ('bit', 10542),
#  ('comedy', 10452),
#  ('down', 10440),
#  ('music', 10428),
#  ('must', 10368),
#  ('take', 10254),
#  ('saw', 10152),
#  ('long', 10140),
#  ('right', 10128),
#  ('fun', 10116),
#  ('fact', 10104),
#  ('excellent', 10098),
#  ('around', 10044),
#  ('didn', 10032),
#  ('without', 10026),
#  ('thing', 9972),
#  ('thought', 9834),
#  ('got', 9810),
#  ('each', 9780),
#  ('day', 9684),
#  ('feel', 9582),
#  ('seems', 9576),
#  ('come', 9564),
#  ('done', 9516),
#  ('beautiful', 9480),
#  ('especially', 9432),
#  ('played', 9426),
#  ('almost', 9396),
#  ('want', 9372),
#  ('yet', 9336),
#  ('give', 9318),
#  ('pretty', 9294),
#  ('last', 9258),
#  ('since', 9114),
#  ('different', 9024),
#  ('although', 9006),
#  ('gets', 8940),
#  ('true', 8922),
#  ('interesting', 8886),
#  ('job', 8820),
#  ('enough', 8730),
#  ('our', 8724),
#  ('shows', 8682),
#  ('horror', 8646),
#  ('woman', 8634),
#  ('tv', 8400),
#  ('probably', 8388),
#  ('father', 8370),
#  ('original', 8358),
#  ('girl', 8340),
#  ('point', 8274),
#  ('plays', 8268),
#  ('wonderful', 8232),
#  ('course', 8148),
#  ('far', 8148),
#  ('john', 8100),
#  ('rather', 8040),
#  ('isn', 7968),
#  ('ll', 7956),
#  ('dvd', 7944),
#  ('later', 7944),
#  ('war', 7860),
#  ('whole', 7860),
#  ('d', 7842),
#  ('found', 7836),
#  ('away', 7836),
#  ('screen', 7830),
#  ('nothing', 7800),
#  ('year', 7782),
#  ('once', 7776),
#  ('hard', 7764),
#  ('together', 7680),
#  ('am', 7662),
#  ('set', 7662),
#  ('having', 7596),
#  ('making', 7590),
#  ('place', 7578),
#  ('comes', 7560),
#  ('might', 7560),
#  ('sure', 7518),
#  ('american', 7488),
#  ('play', 7470),
#  ('kind', 7464),
#  ('takes', 7452),
#  ('perfect', 7452),
#  ('performances', 7422),
#  ('himself', 7380),
#  ('everyone', 7326),
#  ('worth', 7326),
#  ('anyone', 7284),
#  ('actor', 7218),
#  ('three', 7206),
#  ('wife', 7176),
#  ('classic', 7152),
#  ('goes', 7116),
#  ('ending', 7068),
#  ('version', 7008),
#  ('star', 6894),
#  ('enjoy', 6876),
#  ('book', 6852),
#  ('nice', 6792),
#  ('everything', 6768),
#  ('during', 6744),
#  ('put', 6708),
#  ('seeing', 6666),
#  ('least', 6612),
#  ('house', 6600),
#  ('high', 6570),
#  ('watched', 6564),
#  ('loved', 6522),
#  ('men', 6522),
#  ('night', 6492),
#  ('anything', 6450),
#  ('believe', 6426),
#  ('guy', 6426),
#  ('top', 6378),
#  ('amazing', 6348),
#  ('hollywood', 6336),
#  ('looking', 6318),
#  ('main', 6264),
#  ('definitely', 6258),
#  ('gives', 6186),
#  ('home', 6174),
#  ('seem', 6168),
#  ('episode', 6138),
#  ('sense', 6120),
#  ('audience', 6120),
#  ('truly', 6102),
#  ('special', 6066),
#  ('short', 6054),
#  ('fan', 6054),
#  ('second', 6054),
#  ('mind', 6030),
#  ('human', 6006),
#  ('recommend', 5994),
#  ('full', 5976),
#  ('black', 5970),
#  ('help', 5946),
#  ('along', 5934),
#  ('trying', 5922),
#  ('small', 5916),
#  ('death', 5910),
#  ('friends', 5886),
#  ('remember', 5844),
#  ('often', 5820),
#  ('said', 5796),
#  ('favorite', 5772),
#  ('heart', 5754),
#  ('early', 5742),
#  ('left', 5736),
#  ('until', 5730),
#  ('let', 5724),
#  ('script', 5724),
#  ('maybe', 5622),
#  ('today', 5616),
#  ('less', 5604),
#  ('live', 5604),
#  ('moments', 5598),
#  ('others', 5574),
#  ('brilliant', 5556),
#  ('shot', 5550),
#  ('liked', 5538),
#  ('become', 5496),
#  ('won', 5490),
#  ('used', 5460),
#  ('style', 5442),
#  ('mother', 5370),
#  ('lives', 5364),
#  ('came', 5358),
#  ('stars', 5340),
#  ('cinema', 5334),
#  ('looks', 5310),
#  ('perhaps', 5304),
#  ('read', 5292),
#  ('enjoyed', 5274),
#  ('boy', 5250),
#  ('drama', 5238),
#  ('highly', 5226),
#  ('given', 5220),
#  ('playing', 5202),
#  ('use', 5184),
#  ('next', 5154),
#  ('women', 5148),
#  ('fine', 5142),
#  ('effects', 5136),
#  ('kids', 5124),
#  ('entertaining', 5118),
#  ('need', 5112),
#  ('line', 5100),
#  ('works', 5088),
#  ('someone', 5082),
#  ('mr', 5016),
#  ('simply', 5010),
#  ('children', 4998),
#  ('picture', 4998),
#  ('keep', 4986),
#  ('friend', 4986),
#  ('face', 4986),
#  ('dark', 4980),
#  ('overall', 4968),
#  ('certainly', 4968),
#  ('minutes', 4962),
#  ('wasn', 4944),
#  ('history', 4932),
#  ('finally', 4920),
#  ('couple', 4896),
#  ('against', 4890),
#  ('son', 4854),
#  ('understand', 4848),
#  ('lost', 4842),
#  ('michael', 4830),
#  ('else', 4806),
#  ('throughout', 4788),
#  ('fans', 4782),
#  ('city', 4752),
#  ('reason', 4734),
#  ('written', 4722),
#  ('production', 4722),
#  ('several', 4704),
#  ('school', 4698),
#  ('rest', 4686),
#  ('based', 4686),
#  ('try', 4680),
#  ('dead', 4656),
#  ('hope', 4650),
#  ('strong', 4608),
#  ('white', 4590),
#  ('tell', 4554),
#  ('itself', 4548),
#  ('half', 4518),
#  ('person', 4494),
#  ('sometimes', 4476),
#  ('start', 4464),
#  ('past', 4464),
#  ('genre', 4458),
#  ('beginning', 4434),
#  ('final', 4434),
#  ('town', 4428),
#  ('art', 4404),
#  ('humor', 4392),
#  ('game', 4392),
#  ('yes', 4386),
#  ('idea', 4386),
#  ('late', 4380),
#  ('despite', 4374),
#  ('becomes', 4374),
#  ('able', 4356),
#  ('case', 4356),
#  ('money', 4338),
#  ('completely', 4326),
#  ('child', 4326),
#  ('side', 4314),
#  ('camera', 4296),
#  ('getting', 4284),
#  ('instead', 4272),
#  ('soon', 4212),
#  ('under', 4200),
#  ('viewer', 4194),
#  ('age', 4182),
#  ('stories', 4176),
#  ('days', 4176),
#  ('felt', 4164),
#  ('simple', 4164),
#  ('roles', 4158),
#  ('video', 4128),
#  ('name', 4098),
#  ('either', 4098),
#  ('doing', 4062),
#  ('turns', 4044),
#  ('wants', 4026),
#  ('close', 4026),
#  ('title', 4014),
#  ('wrong', 4008),
#  ('went', 3996),
#  ('james', 3990),
#  ('evil', 3954),
#  ('episodes', 3942),
#  ('budget', 3942),
#  ('relationship', 3930),
#  ('piece', 3918),
#  ('fantastic', 3918),
#  ('david', 3906),
#  ('turn', 3888),
#  ('murder', 3876),
#  ('parts', 3870),
#  ('brother', 3864),
#  ('head', 3858),
#  ('absolutely', 3858),
#  ('experience', 3852),
#  ('eyes', 3846),
#  ('sex', 3828),
#  ('direction', 3822),
#  ('called', 3822),
#  ('directed', 3816),
#  ('lines', 3804),
#  ('behind', 3798),
#  ('sort', 3792),
#  ('actress', 3786),
#  ('lead', 3780),
#  ('oscar', 3768),
#  ('example', 3762),
#  ('including', 3762),
#  ('musical', 3750),
#  ('known', 3750),
#  ('chance', 3726),
#  ('score', 3720),
#  ('already', 3714),
#  ('feeling', 3714),
#  ('hit', 3714),
#  ('voice', 3690),
#  ('moment', 3672),
#  ('living', 3672),
#  ('low', 3660),
#  ('supporting', 3660),
#  ('ago', 3654),
#  ('themselves', 3648),
#  ('reality', 3630),
#  ('hilarious', 3630),
#  ('jack', 3624),
#  ('told', 3618),
#  ('hand', 3606),
#  ('dialogue', 3600),
#  ('moving', 3600),
#  ('quality', 3600),
#  ('happy', 3594),
#  ('song', 3594),
#  ('matter', 3588),
#  ('paul', 3588),
#  ('light', 3564),
#  ('future', 3558),
#  ('entire', 3552),
#  ('finds', 3546),
#  ('gave', 3534),
#  ('laugh', 3522),
#  ('released', 3516),
#  ('expect', 3504),
#  ('fight', 3486),
#  ('particularly', 3480),
#  ('cinematography', 3474),
#  ('police', 3474),
#  ('type', 3468),
#  ('sound', 3468),
#  ('whose', 3468),
#  ('enjoyable', 3438),
#  ('view', 3438),
#  ('husband', 3432),
#  ('daughter', 3432),
#  ('number', 3432),
#  ('romantic', 3432),
#  ('documentary', 3426),
#  ('self', 3420),
#  ('took', 3414),
#  ('superb', 3414),
#  ('modern', 3414),
#  ('robert', 3414),
#  ('mean', 3396),
#  ('shown', 3378),
#  ('coming', 3366),
#  ('important', 3360),
#  ('king', 3354),
#  ('leave', 3354),
#  ('change', 3348),
#  ('wanted', 3330),
#  ('somewhat', 3330),
#  ('tells', 3324),
#  ('career', 3312),
#  ('run', 3312),
#  ('events', 3312),
#  ('country', 3312),
#  ('season', 3300),
#  ('heard', 3300),
#  ('girls', 3294),
#  ('greatest', 3294),
#  ('etc', 3282),
#  ('care', 3276),
#  ('starts', 3270),
#  ('english', 3252),
#  ('killer', 3246),
#  ('tale', 3240),
#  ('totally', 3240),
#  ('animation', 3240),
#  ('guys', 3240),
#  ('usual', 3234),
#  ('miss', 3210),
#  ('opinion', 3210),
#  ('violence', 3186),
#  ('easy', 3186),
#  ('songs', 3180),
#  ('british', 3168),
#  ('says', 3156),
#  ('realistic', 3150),
#  ('writing', 3144),
#  ('writer', 3132),
#  ('act', 3132),
#  ('comic', 3126),
#  ('thriller', 3114),
#  ('television', 3102),
#  ('power', 3096),
#  ('ones', 3090),
#  ('kid', 3084),
#  ('york', 3078),
#  ('novel', 3078),
#  ('problem', 3072),
#  ('alone', 3072),
#  ('attention', 3054),
#  ('involved', 3048),
#  ('kill', 3042),
#  ('extremely', 3042),
#  ('seemed', 3036),
#  ('hero', 3030),
#  ('french', 3030),
#  ('rock', 3024),
#  ('stuff', 3006),
#  ('wish', 2994),
#  ('begins', 2988),
#  ('taken', 2982),
#  ('sad', 2982),
#  ('ways', 2976),
#  ('richard', 2970),
#  ('knows', 2964),
#  ('atmosphere', 2958),
#  ('taking', 2946),
#  ('similar', 2946),
#  ('car', 2946),
#  ('surprised', 2946),
#  ('perfectly', 2940),
#  ('george', 2940),
#  ('sequence', 2934),
#  ('team', 2934),
#  ('across', 2934),
#  ('eye', 2934),
#  ('among', 2928),
#  ('room', 2928),
#  ('serious', 2928),
#  ('powerful', 2928),
#  ('due', 2928),
#  ('strange', 2922),
#  ('order', 2922),
#  ('b', 2922),
#  ('cannot', 2922),
#  ('beauty', 2916),
#  ('famous', 2910),
#  ('tries', 2904),
#  ('happened', 2904),
#  ('myself', 2904),
#  ('herself', 2904),
#  ('class', 2898),
#  ('four', 2892),
#  ('cool', 2886),
#  ('release', 2874),
#  ('anyway', 2874),
#  ('theme', 2874),
#  ('opening', 2868),
#  ('entertainment', 2862),
#  ('ends', 2850),
#  ('unique', 2850),
#  ('exactly', 2850),
#  ('slow', 2850),
#  ('o', 2844),
#  ('level', 2844),
#  ('easily', 2844),
#  ('red', 2844),
#  ('interest', 2832),
#  ('happen', 2826),
#  ('crime', 2820),
#  ('viewing', 2808),
#  ('memorable', 2802),
#  ('sets', 2802),
#  ('group', 2796),
#  ('stop', 2796),
#  ('problems', 2778),
#  ('sister', 2778),
#  ('dance', 2778),
#  ('message', 2778),
#  ('working', 2778),
#  ('knew', 2772),
#  ('nature', 2766),
#  ('mystery', 2766),
#  ('bring', 2760),
#  ('brought', 2754),
#  ('thinking', 2754),
#  ('believable', 2754),
#  ('mostly', 2748),
#  ('couldn', 2742),
#  ('disney', 2742),
#  ('society', 2736),
#  ('lady', 2730),
#  ('within', 2730),
#  ('blood', 2724),
#  ('parents', 2718),
#  ('upon', 2718),
#  ('viewers', 2718),
#  ('peter', 2712),
#  ('meets', 2712),
#  ('tom', 2712),
#  ('form', 2712),
#  ('soundtrack', 2712),
#  ('usually', 2712),
#  ('local', 2700),
#  ('certain', 2688),
#  ('follow', 2688),
#  ('whether', 2682),
#  ('possible', 2676),
#  ('emotional', 2670),
#  ('de', 2664),
#  ('killed', 2664),
#  ('above', 2664),
#  ('middle', 2658),
#  ('god', 2658),
#  ('flick', 2652),
#  ('happens', 2652),
#  ('needs', 2652),
#  ('masterpiece', 2646),
#  ('period', 2640),
#  ('major', 2640),
#  ('haven', 2634),
#  ('named', 2634),
#  ('particular', 2628),
#  ('th', 2628),
#  ('feature', 2622),
#  ('earth', 2622),
#  ('stand', 2616),
#  ('words', 2610),
#  ('typical', 2610),
#  ('elements', 2598),
#  ('obviously', 2598),
#  ('romance', 2586),
#  ('jane', 2580),
#  ('yourself', 2562),
#  ('showing', 2562),
#  ('brings', 2556),
#  ('fantasy', 2556),
#  ('america', 2538),
#  ('guess', 2538),
#  ('huge', 2532),
#  ('unfortunately', 2532),
#  ('running', 2526),
#  ('indeed', 2526),
#  ('talent', 2520),
#  ('stage', 2514),
#  ('started', 2508),
#  ('leads', 2502),
#  ('sweet', 2502),
#  ('japanese', 2502),
#  ('deal', 2496),
#  ('poor', 2496),
#  ('personal', 2478),
#  ('incredible', 2478),
#  ('fast', 2472),
#  ('deep', 2460),
#  ('became', 2460),
#  ('hours', 2454),
#  ('giving', 2448),
#  ('nearly', 2448),
#  ('dream', 2448),
#  ('turned', 2442),
#  ('clearly', 2442),
#  ('near', 2436),
#  ('obvious', 2436),
#  ('cut', 2430),
#  ('surprise', 2430),
#  ('body', 2424),
#  ('era', 2424),
#  ('female', 2418),
#  ('five', 2418),
#  ('hour', 2418),
#  ('note', 2394),
#  ('learn', 2388),
#  ('truth', 2388),
#  ('match', 2382),
#  ('except', 2382),
#  ('tony', 2382),
#  ('feels', 2382),
#  ('clear', 2364),
#  ('complete', 2364),
#  ('filmed', 2364),
#  ('keeps', 2358),
#  ('older', 2358),
#  ('eventually', 2358),
#  ('street', 2358),
#  ('lots', 2358),
#  ('buy', 2352),
#  ('stewart', 2346),
#  ('william', 2346),
#  ('fall', 2340),
#  ('meet', 2340),
#  ('joe', 2340),
#  ('talking', 2334),
#  ('unlike', 2334),
#  ('difficult', 2334),
#  ('shots', 2334),
#  ('rating', 2334),
#  ('dramatic', 2328),
#  ('means', 2328),
#  ('situation', 2316),
#  ('present', 2316),
#  ('subject', 2316),
#  ('wonder', 2316),
#  ('appears', 2316),
#  ('comments', 2310),
#  ('sequences', 2298),
#  ('lee', 2298),
#  ('general', 2298),
#  ('points', 2292),
#  ('earlier', 2292),
#  ('gone', 2274),
#  ('check', 2274),
#  ('recommended', 2268),
#  ('ten', 2268),
#  ('suspense', 2268),
#  ('business', 2262),
#  ('third', 2262),
#  ('leaves', 2250),
#  ('beyond', 2250),
#  ('talk', 2250),
#  ('portrayal', 2244),
#  ('beautifully', 2238),
#  ('single', 2232),
#  ('bill', 2232),
#  ('plenty', 2226),
#  ('word', 2226),
#  ('whom', 2220),
#  ('falls', 2220),
#  ('scary', 2214),
#  ('non', 2214),
#  ('figure', 2214),
#  ('battle', 2214),
#  ('return', 2208),
#  ('using', 2208),
#  ('add', 2202),
#  ('doubt', 2202),
#  ('success', 2196),
#  ('hear', 2196),
#  ('solid', 2196),
#  ('jokes', 2190),
#  ('oh', 2190),
#  ('touching', 2190),
#  ('political', 2190),
#  ('awesome', 2184),
#  ('boys', 2184),
#  ('hell', 2184),
#  ('dog', 2172),
#  ('sexual', 2172),
#  ('recently', 2172),
#  ('please', 2166),
#  ('wouldn', 2166),
#  ('features', 2166),
#  ('straight', 2166),
#  ('setting', 2160),
#  ('lack', 2160),
#  ('forget', 2160),
#  ('married', 2154),
#  ('mark', 2154),
#  ('social', 2142),
#  ('adventure', 2136),
#  ('interested', 2136),
#  ('brothers', 2130),
#  ('sees', 2130),
#  ('terrific', 2130),
#  ('actual', 2130),
#  ('move', 2124),
#  ('call', 2124),
#  ('theater', 2118),
#  ('various', 2118),
#  ('dr', 2118),
#  ('animated', 2112),
#  ('western', 2106),
#  ('baby', 2100),
#  ('space', 2100),
#  ('disappointed', 2088),
#  ('leading', 2088),
#  ('portrayed', 2076),
#  ('aren', 2076),
#  ('smith', 2070),
#  ('screenplay', 2070),
#  ('hate', 2064),
#  ('towards', 2064),
#  ('noir', 2058),
#  ('decent', 2052),
#  ('kelly', 2052),
#  ('outstanding', 2052),
#  ('directors', 2046),
#  ('journey', 2046),
#  ('effective', 2040),
#  ('none', 2040),
#  ('looked', 2040),
#  ('mary', 2034),
#  ('caught', 2034),
#  ('storyline', 2034),
#  ('fi', 2034),
#  ('sci', 2034),
#  ('cold', 2034),
#  ('rich', 2028),
#  ('charming', 2028),
#  ('harry', 2022),
#  ('popular', 2022),
#  ('rare', 2022),
#  ('manages', 2022),
#  ('spirit', 2016),
#  ('appreciate', 2010),
#  ('open', 2010),
#  ('moves', 2004),
#  ('acted', 2004),
#  ('basically', 2004),
#  ('boring', 1998),
#  ('inside', 1998),
#  ('subtle', 1998),
#  ('century', 1998),
#  ('deserves', 1998),
#  ('mention', 1998),
#  ('pace', 1998),
#  ('familiar', 1992),
#  ('background', 1992),
#  ('ben', 1986),
#  ('creepy', 1980),
#  ('supposed', 1980),
#  ('secret', 1974),
#  ('jim', 1968),
#  ('die', 1968),
#  ('natural', 1962),
#  ('effect', 1962),
#  ('question', 1962),
#  ('impressive', 1956),
#  ('language', 1956),
#  ('rate', 1956),
#  ('intelligent', 1950),
#  ('saying', 1950),
#  ('telling', 1944),
#  ('scott', 1944),
#  ('material', 1944),
#  ('realize', 1944),
#  ('singing', 1938),
#  ('dancing', 1932),
#  ('imagine', 1926),
#  ('visual', 1926),
#  ('adult', 1926),
#  ('office', 1920),
#  ('kept', 1920),
#  ('uses', 1914),
#  ('wait', 1908),
#  ('stunning', 1908),
#  ('pure', 1908),
#  ('seriously', 1902),
#  ('previous', 1902),
#  ('copy', 1902),
#  ('review', 1902),
#  ('created', 1896),
#  ('hot', 1896),
#  ('reading', 1896),
#  ('create', 1896),
#  ('magic', 1896),
#  ('somehow', 1896),
#  ('crazy', 1890),
#  ('attempt', 1890),
#  ('air', 1890),
#  ('escape', 1890),
#  ('stay', 1890),
#  ('frank', 1890),
#  ('hands', 1884),
#  ('filled', 1878),
#  ('expected', 1872),
#  ('surprisingly', 1872),
#  ('average', 1872),
#  ('complex', 1866),
#  ('quickly', 1860),
#  ('studio', 1860),
#  ('successful', 1860),
#  ('male', 1854),
#  ('plus', 1854),
#  ('co', 1842),
#  ('minute', 1836),
#  ('following', 1836),
#  ('images', 1836),
#  ('exciting', 1836),
#  ('casting', 1836),
#  ('german', 1830),
#  ('e', 1830),
#  ('members', 1830),
#  ('follows', 1830),
#  ('reasons', 1830),
#  ('themes', 1830),
#  ('edge', 1824),
#  ('cute', 1824),
#  ('touch', 1824),
#  ('genius', 1824),
#  ('free', 1824),
#  ('outside', 1818),
#  ('younger', 1812),
#  ('reviews', 1812),
#  ('admit', 1812),
#  ('ok', 1812),
#  ('odd', 1806),
#  ('fighting', 1806),
#  ('master', 1806),
#  ('thanks', 1800),
#  ('break', 1800),
#  ('comment', 1800),
#  ('recent', 1800),
#  ('apart', 1794),
#  ('emotions', 1788),
#  ('lovely', 1788),
#  ('begin', 1788),
#  ('doctor', 1782),
#  ('party', 1782),
#  ('italian', 1782),
#  ('clever', 1776),
#  ('la', 1776),
#  ...]

# %%
# Examine the counts of the most common words in negative reviews
negative_counts.most_common()
# Out:
# [('', 2245848),
#  ('.', 1005228),
#  ('the', 980334),
#  ('a', 475926),
#  ('and', 446310),
#  ('of', 414054),
#  ('to', 413844),
#  ('br', 315822),
#  ('is', 300498),
#  ('it', 289962),
#  ('i', 281280),
#  ('in', 262518),
#  ('this', 245520),
#  ('that', 225690),
#  ('s', 189276),
#  ('was', 157746),
#  ('movie', 149790),
#  ('for', 131562),
#  ('but', 130686),
#  ('with', 125268),
#  ('as', 123750),
#  ('t', 122166),
#  ('film', 115308),
#  ('you', 105294),
#  ('on', 103152),
#  ('not', 98124),
#  ('have', 90864),
#  ('are', 87738),
#  ('be', 87246),
#  ('he', 83136),
#  ('one', 78804),
#  ('they', 78066),
#  ('at', 73674),
#  ('his', 72882),
#  ('all', 72216),
#  ('so', 68778),
#  ('like', 67428),
#  ('there', 64650),
#  ('just', 63714),
#  ('by', 63294),
#  ('or', 61632),
#  ('an', 61596),
#  ('who', 59814),
#  ('from', 58386),
#  ('if', 57108),
#  ('about', 54366),
#  ('out', 53874),
#  ('what', 50532),
#  ('some', 49836),
#  ('no', 48858),
#  ('her', 47682),
#  ('even', 46122),
#  ('can', 45918),
#  ('has', 45624),
#  ('good', 44538),
#  ('bad', 44406),
#  ('would', 42216),
#  ('up', 41820),
#  ('only', 40686),
#  ('more', 40380),
#  ('when', 40356),
#  ('she', 38664),
#  ('really', 37572),
#  ('time', 37254),
#  ('had', 36852),
#  ('my', 36090),
#  ('were', 36006),
#  ('which', 34680),
#  ('very', 34584),
#  ('me', 33636),
#  ('see', 32712),
#  ('don', 32016),
#  ('we', 31968),
#  ('their', 31668),
#  ('do', 31416),
#  ('story', 31248),
#  ('than', 31098),
#  ('been', 30600),
#  ('much', 30468),
#  ('get', 30222),
#  ('because', 29796),
#  ('people', 28836),
#  ('then', 28566),
#  ('make', 28332),
#  ('how', 28128),
#  ('could', 28116),
#  ('any', 27948),
#  ('into', 27402),
#  ('made', 27246),
#  ('first', 25836),
#  ('other', 25830),
#  ('well', 25524),
#  ('too', 25044),
#  ('them', 24990),
#  ('plot', 24924),
#  ('movies', 24480),
#  ('acting', 24336),
#  ('will', 23958),
#  ('way', 23934),
#  ('most', 23514),
#  ('him', 23148),
#  ('after', 23028),
#  ('its', 21930),
#  ('think', 21858),
#  ('also', 21648),
#  ('characters', 21600),
#  ('off', 21402),
#  ('watch', 21300),
#  ('did', 21036),
#  ('character', 21036),
#  ('why', 20778),
#  ('being', 20358),
#  ('better', 20148),
#  ('know', 20004),
#  ('over', 19896),
#  ('seen', 19590),
#  ('ever', 19578),
#  ('never', 19554),
#  ('your', 19398),
#  ('where', 19314),
#  ('two', 19038),
#  ('little', 18576),
#  ('films', 18462),
#  ('here', 18162),
#  ('m', 18000),
#  ('nothing', 17940),
#  ('say', 17892),
#  ('end', 17724),
#  ('something', 17652),
#  ('should', 17520),
#  ('many', 17454),
#  ('does', 17226),
#  ('thing', 17196),
#  ('show', 17172),
#  ('ve', 16974),
#  ('scene', 16896),
#  ('scenes', 16710),
#  ('these', 16344),
#  ('go', 16302),
#  ('didn', 15876),
#  ('great', 15840),
#  ('watching', 15840),
#  ('re', 15720),
#  ('doesn', 15606),
#  ('through', 15360),
#  ('such', 15264),
#  ('man', 15096),
#  ('worst', 14880),
#  ('actually', 14694),
#  ('actors', 14622),
#  ('life', 14574),
#  ('back', 14544),
#  ('while', 14508),
#  ('director', 14430),
#  ('funny', 14016),
#  ('going', 13914),
#  ('still', 13698),
#  ('another', 13524),
#  ('look', 13482),
#  ('now', 13422),
#  ('old', 13290),
#  ('those', 13272),
#  ('real', 13020),
#  ('few', 12948),
#  ('love', 12912),
#  ('horror', 12900),
#  ('before', 12882),
#  ('want', 12846),
#  ('minutes', 12756),
#  ('pretty', 12690),
#  ('best', 12564),
#  ('though', 12546),
#  ('same', 12486),
#  ('script', 12444),
#  ('work', 12162),
#  ('every', 12150),
#  ('seems', 12138),
#  ('least', 12066),
#  ('enough', 11982),
#  ('down', 11928),
#  ('original', 11898),
#  ('guy', 11784),
#  ('got', 11712),
#  ('around', 11658),
#  ('part', 11652),
#  ('lot', 11352),
#  ('anything', 11244),
#  ('find', 11160),
#  ('new', 11124),
#  ('again', 11094),
#  ('isn', 11094),
#  ('point', 11070),
#  ('fact', 11034),
#  ('things', 11034),
#  ('give', 10938),
#  ('makes', 10884),
#  ('take', 10800),
#  ('thought', 10788),
#  ('d', 10620),
#  ('whole', 10608),
#  ('long', 10566),
#  ('years', 10554),
#  ('however', 10440),
#  ('gets', 10284),
#  ('making', 10170),
#  ('cast', 10164),
#  ('big', 9972),
#  ('might', 9948),
#  ('interesting', 9888),
#  ('money', 9828),
#  ('us', 9768),
#  ('right', 9750),
#  ('far', 9714),
#  ('quite', 9576),
#  ('come', 9570),
#  ('without', 9570),
#  ('almost', 9444),
#  ('ll', 9402),
#  ('action', 9396),
#  ('awful', 9342),
#  ('kind', 9234),
#  ('reason', 9204),
#  ('am', 9180),
#  ('looks', 9168),
#  ('must', 9132),
#  ('done', 9060),
#  ('comedy', 9024),
#  ('someone', 8940),
#  ('trying', 8916),
#  ('wasn', 8904),
#  ('poor', 8886),
#  ('boring', 8868),
#  ('instead', 8868),
#  ('saw', 8850),
#  ('away', 8814),
#  ('girl', 8778),
#  ('probably', 8664),
#  ('believe', 8604),
#  ('sure', 8598),
#  ('looking', 8580),
#  ('stupid', 8568),
#  ('anyone', 8508),
#  ('times', 8436),
#  ('world', 8424),
#  ('maybe', 8424),
#  ('rather', 8364),
#  ('terrible', 8346),
#  ('may', 8340),
#  ('last', 8340),
#  ('since', 8328),
#  ('let', 8310),
#  ('tv', 8292),
#  ('hard', 8244),
#  ('between', 8244),
#  ('waste', 8148),
#  ('woman', 8136),
#  ('feel', 8124),
#  ('effects', 8088),
#  ('half', 8046),
#  ('own', 7998),
#  ('young', 7902),
#  ('music', 7896),
#  ('idea', 7872),
#  ('sense', 7836),
#  ('bit', 7788),
#  ('having', 7680),
#  ('book', 7668),
#  ('found', 7602),
#  ('put', 7578),
#  ('series', 7578),
#  ('goes', 7536),
#  ('worse', 7494),
#  ('said', 7380),
#  ('comes', 7344),
#  ('role', 7332),
#  ('main', 7320),
#  ('else', 7194),
#  ('everything', 7182),
#  ('yet', 7176),
#  ('low', 7134),
#  ('screen', 7128),
#  ('supposed', 7116),
#  ('actor', 7110),
#  ('either', 7098),
#  ('ending', 7074),
#  ('budget', 7074),
#  ('audience', 7068),
#  ('set', 7062),
#  ('family', 7020),
#  ('left', 7014),
#  ('completely', 7008),
#  ('both', 6948),
#  ('wrong', 6930),
#  ('always', 6906),
#  ('course', 6888),
#  ('place', 6888),
#  ('seem', 6882),
#  ('watched', 6852),
#  ('day', 6792),
#  ('simply', 6780),
#  ('shot', 6756),
#  ('mean', 6702),
#  ('special', 6612),
#  ('dead', 6606),
#  ('three', 6564),
#  ('house', 6510),
#  ('oh', 6504),
#  ('night', 6498),
#  ('read', 6492),
#  ('less', 6402),
#  ('high', 6396),
#  ('year', 6384),
#  ('camera', 6366),
#  ('worth', 6342),
#  ('our', 6336),
#  ('try', 6306),
#  ('sex', 6276),
#  ('horrible', 6276),
#  ('video', 6258),
#  ('black', 6234),
#  ('although', 6216),
#  ('couldn', 6216),
#  ('once', 6198),
#  ('rest', 6132),
#  ('dvd', 6126),
#  ('line', 6108),
#  ('played', 6102),
#  ('fun', 6042),
#  ('during', 6036),
#  ('production', 6018),
#  ('everyone', 6012),
#  ('play', 5958),
#  ('mind', 5940),
#  ('version', 5934),
#  ('kids', 5934),
#  ('seeing', 5928),
#  ('american', 5880),
#  ('given', 5868),
#  ('used', 5814),
#  ('performance', 5808),
#  ('especially', 5778),
#  ('together', 5778),
#  ('tell', 5754),
#  ('women', 5748),
#  ('start', 5736),
#  ('need', 5730),
#  ('second', 5718),
#  ('each', 5700),
#  ('takes', 5700),
#  ('wife', 5664),
#  ('dialogue', 5652),
#  ('use', 5640),
#  ('problem', 5628),
#  ('star', 5604),
#  ('unfortunately', 5586),
#  ('himself', 5574),
#  ('doing', 5556),
#  ('death', 5532),
#  ('name', 5526),
#  ('lines', 5514),
#  ('killer', 5484),
#  ('getting', 5478),
#  ('help', 5430),
#  ('couple', 5412),
#  ('fan', 5412),
#  ('head', 5388),
#  ('crap', 5370),
#  ('guess', 5328),
#  ('piece', 5304),
#  ('nice', 5280),
#  ('different', 5268),
#  ('school', 5256),
#  ('later', 5250),
#  ('entire', 5214),
#  ('shows', 5160),
#  ('next', 5148),
#  ('john', 5148),
#  ('short', 5142),
#  ('seemed', 5142),
#  ('hollywood', 5100),
#  ('home', 5088),
#  ('person', 5076),
#  ('true', 5076),
#  ('absolutely', 5052),
#  ('sort', 5040),
#  ('care', 5034),
#  ('understand', 5016),
#  ('plays', 5010),
#  ('felt', 5004),
#  ('written', 4974),
#  ('title', 4968),
#  ('men', 4932),
#  ('until', 4926),
#  ('flick', 4896),
#  ('decent', 4890),
#  ('face', 4884),
#  ('friends', 4860),
#  ('case', 4842),
#  ('stars', 4842),
#  ('job', 4842),
#  ('itself', 4824),
#  ('yes', 4806),
#  ('perhaps', 4800),
#  ('went', 4782),
#  ('wanted', 4782),
#  ('called', 4776),
#  ('annoying', 4770),
#  ('tries', 4740),
#  ('ridiculous', 4740),
#  ('laugh', 4728),
#  ('evil', 4722),
#  ('along', 4716),
#  ('top', 4710),
#  ('hour', 4704),
#  ('full', 4698),
#  ('writing', 4680),
#  ('came', 4680),
#  ('keep', 4620),
#  ('totally', 4602),
#  ('playing', 4596),
#  ('god', 4590),
#  ('won', 4584),
#  ('guys', 4578),
#  ('already', 4572),
#  ('gore', 4542),
#  ('direction', 4488),
#  ('save', 4476),
#  ('lost', 4470),
#  ('example', 4464),
#  ('sound', 4452),
#  ('war', 4446),
#  ('attempt', 4410),
#  ('except', 4398),
#  ('car', 4398),
#  ('moments', 4392),
#  ('blood', 4392),
#  ('obviously', 4380),
#  ('act', 4374),
#  ('remember', 4368),
#  ('kill', 4362),
#  ('father', 4356),
#  ('white', 4356),
#  ('truly', 4356),
#  ('b', 4350),
#  ('thinking', 4320),
#  ('finally', 4296),
#  ('ok', 4296),
#  ('turn', 4266),
#  ('quality', 4206),
#  ('lack', 4188),
#  ('style', 4164),
#  ('wouldn', 4158),
#  ('cheap', 4146),
#  ('none', 4140),
#  ('please', 4116),
#  ('kid', 4116),
#  ('boy', 4110),
#  ('seriously', 4104),
#  ('lead', 4080),
#  ('dull', 4062),
#  ('children', 4056),
#  ('starts', 4050),
#  ('stuff', 4038),
#  ('hope', 4032),
#  ('looked', 4020),
#  ('recommend', 4014),
#  ('under', 4008),
#  ('killed', 4002),
#  ('run', 4002),
#  ('enjoy', 3996),
#  ('others', 3996),
#  ('myself', 3978),
#  ('etc', 3978),
#  ('girls', 3972),
#  ('beginning', 3972),
#  ('against', 3972),
#  ('obvious', 3960),
#  ('small', 3960),
#  ('hell', 3954),
#  ('slow', 3942),
#  ('hand', 3936),
#  ('wonder', 3912),
#  ('lame', 3912),
#  ('becomes', 3906),
#  ('picture', 3906),
#  ('based', 3900),
#  ('early', 3888),
#  ('behind', 3876),
#  ('poorly', 3864),
#  ('avoid', 3852),
#  ('complete', 3840),
#  ('apparently', 3840),
#  ('happens', 3834),
#  ('anyway', 3828),
#  ('classic', 3822),
#  ('several', 3816),
#  ('despite', 3810),
#  ('certainly', 3810),
#  ('episode', 3810),
#  ('often', 3786),
#  ('cut', 3780),
#  ('writer', 3780),
#  ('gave', 3768),
#  ('predictable', 3768),
#  ('mother', 3768),
#  ('become', 3762),
#  ('close', 3750),
#  ('fans', 3744),
#  ('saying', 3726),
#  ('scary', 3714),
#  ('live', 3708),
#  ('stop', 3708),
#  ('wants', 3702),
#  ('self', 3690),
#  ('mr', 3672),
#  ('jokes', 3666),
#  ('friend', 3666),
#  ('cannot', 3660),
#  ('overall', 3654),
#  ('cinema', 3624),
#  ('child', 3618),
#  ('silly', 3606),
#  ('beautiful', 3576),
#  ('human', 3570),
#  ('expect', 3564),
#  ('liked', 3558),
#  ('happened', 3552),
#  ('bunch', 3540),
#  ('entertaining', 3540),
#  ('final', 3528),
#  ('actress', 3528),
#  ('performances', 3504),
#  ('says', 3504),
#  ('humor', 3462),
#  ('turns', 3462),
#  ('eyes', 3456),
#  ('themselves', 3456),
#  ('hours', 3444),
#  ('happen', 3438),
#  ('days', 3432),
#  ('basically', 3432),
#  ('running', 3426),
#  ('call', 3414),
#  ('disappointed', 3414),
#  ('involved', 3414),
#  ('directed', 3408),
#  ('group', 3408),
#  ('fight', 3402),
#  ('daughter', 3396),
#  ('talking', 3396),
#  ('body', 3396),
#  ('badly', 3390),
#  ('sorry', 3390),
#  ('viewer', 3378),
#  ('throughout', 3378),
#  ('yourself', 3372),
#  ('extremely', 3372),
#  ('interest', 3366),
#  ('violence', 3366),
#  ('heard', 3366),
#  ('shots', 3354),
#  ('side', 3342),
#  ('word', 3336),
#  ('art', 3330),
#  ('possible', 3324),
#  ('game', 3306),
#  ('dark', 3306),
#  ('hero', 3300),
#  ('alone', 3294),
#  ('type', 3282),
#  ('son', 3282),
#  ('leave', 3282),
#  ('parts', 3276),
#  ('single', 3276),
#  ('gives', 3276),
#  ('started', 3270),
#  ('female', 3258),
#  ('voice', 3246),
#  ('rating', 3246),
#  ('mess', 3246),
#  ('aren', 3240),
#  ('town', 3240),
#  ('drama', 3228),
#  ('definitely', 3222),
#  ('unless', 3216),
#  ('review', 3204),
#  ('able', 3198),
#  ('effort', 3198),
#  ('weak', 3198),
#  ('took', 3186),
#  ('five', 3180),
#  ('non', 3180),
#  ('matter', 3174),
#  ('usually', 3174),
#  ('michael', 3168),
#  ('feeling', 3156),
#  ('huge', 3138),
#  ('sequel', 3132),
#  ('soon', 3126),
#  ('exactly', 3120),
#  ('past', 3114),
#  ('turned', 3108),
#  ('police', 3108),
#  ('tried', 3090),
#  ('middle', 3078),
#  ('talent', 3078),
#  ('genre', 3072),
#  ('zombie', 3060),
#  ('ends', 3054),
#  ('history', 3054),
#  ('straight', 3018),
#  ('coming', 3006),
#  ('serious', 3006),
#  ('opening', 3006),
#  ('moment', 3000),
#  ('lives', 2994),
#  ('sad', 2994),
#  ('particularly', 2988),
#  ('dialog', 2988),
#  ('editing', 2958),
#  ('clearly', 2952),
#  ('earth', 2946),
#  ('beyond', 2946),
#  ('taken', 2940),
#  ('cool', 2940),
#  ('level', 2934),
#  ('dumb', 2934),
#  ('okay', 2928),
#  ('major', 2922),
#  ('fast', 2910),
#  ('premise', 2910),
#  ('stories', 2904),
#  ('joke', 2904),
#  ('wasted', 2898),
#  ('minute', 2898),
#  ('mostly', 2892),
#  ('across', 2892),
#  ('rent', 2892),
#  ('falls', 2886),
#  ('fails', 2886),
#  ('late', 2886),
#  ('mention', 2868),
#  ('theater', 2850),
#  ('sometimes', 2832),
#  ('stay', 2832),
#  ('hit', 2808),
#  ('fine', 2802),
#  ('talk', 2802),
#  ('die', 2796),
#  ('storyline', 2790),
#  ('pointless', 2790),
#  ('taking', 2784),
#  ('order', 2772),
#  ('brother', 2766),
#  ('told', 2760),
#  ('whatever', 2760),
#  ('wish', 2748),
#  ('room', 2736),
#  ('write', 2730),
#  ('appears', 2730),
#  ('career', 2730),
#  ('husband', 2724),
#  ('known', 2724),
#  ('living', 2706),
#  ('ten', 2700),
#  ('sit', 2700),
#  ('words', 2694),
#  ('monster', 2688),
#  ('chance', 2688),
#  ('novel', 2664),
#  ('hate', 2664),
#  ('english', 2658),
#  ('add', 2658),
#  ('somehow', 2646),
#  ('strange', 2640),
#  ('imdb', 2628),
#  ('actual', 2628),
#  ('material', 2622),
#  ('total', 2622),
#  ('killing', 2622),
#  ('ones', 2622),
#  ('knew', 2616),
#  ('king', 2604),
#  ('number', 2604),
#  ('using', 2598),
#  ('power', 2586),
#  ('giving', 2586),
#  ('works', 2586),
#  ('lee', 2586),
#  ('shown', 2586),
#  ('points', 2580),
#  ('possibly', 2580),
#  ('kept', 2580),
#  ('four', 2574),
#  ('local', 2562),
#  ('usual', 2556),
#  ('including', 2550),
#  ('ago', 2544),
#  ('problems', 2544),
#  ('opinion', 2544),
#  ('nudity', 2538),
#  ('age', 2532),
#  ('due', 2526),
#  ('roles', 2520),
#  ('writers', 2514),
#  ('decided', 2514),
#  ('easily', 2508),
#  ('near', 2508),
#  ('flat', 2508),
#  ('experience', 2502),
#  ('murder', 2502),
#  ('reviews', 2496),
#  ('imagine', 2490),
#  ('feels', 2478),
#  ('plain', 2466),
#  ('somewhat', 2466),
#  ('class', 2460),
#  ('score', 2460),
#  ('bring', 2454),
#  ('whether', 2454),
#  ('song', 2454),
#  ('otherwise', 2448),
#  ('average', 2448),
#  ('whose', 2448),
#  ('pathetic', 2442),
#  ('knows', 2442),
#  ('nearly', 2442),
#  ('zombies', 2442),
#  ('cinematography', 2436),
#  ('cheesy', 2436),
#  ('upon', 2436),
#  ('space', 2430),
#  ('city', 2430),
#  ('credits', 2424),
#  ('james', 2418),
#  ('change', 2418),
#  ('lots', 2418),
#  ('entertainment', 2412),
#  ('nor', 2412),
#  ('wait', 2406),
#  ('released', 2400),
#  ('needs', 2394),
#  ('shame', 2388),
#  ('attention', 2376),
#  ('comments', 2364),
#  ('lady', 2358),
#  ('free', 2358),
#  ('bored', 2358),
#  ('clear', 2352),
#  ('expected', 2352),
#  ('needed', 2352),
#  ('view', 2346),
#  ('development', 2340),
#  ('check', 2340),
#  ('doubt', 2340),
#  ('figure', 2334),
#  ('mystery', 2334),
#  ('garbage', 2328),
#  ('excellent', 2328),
#  ('television', 2316),
#  ('sequence', 2316),
#  ('o', 2310),
#  ('sets', 2310),
#  ('laughable', 2304),
#  ('potential', 2304),
#  ('reality', 2292),
#  ('country', 2292),
#  ('light', 2292),
#  ('robert', 2292),
#  ('documentary', 2292),
#  ('general', 2286),
#  ('ask', 2286),
#  ('comic', 2280),
#  ('fall', 2280),
#  ('begin', 2280),
#  ('forced', 2274),
#  ('stand', 2274),
#  ('remake', 2274),
#  ('trash', 2274),
#  ('footage', 2274),
#  ('thriller', 2268),
#  ('songs', 2268),
#  ('gay', 2262),
#  ('within', 2262),
#  ('hardly', 2256),
#  ('gone', 2250),
#  ('above', 2250),
#  ('george', 2244),
#  ('means', 2238),
#  ('sounds', 2238),
#  ('move', 2232),
#  ('directing', 2232),
#  ('david', 2232),
#  ('buy', 2232),
#  ('forward', 2226),
#  ('rock', 2226),
#  ('important', 2226),
#  ('filmed', 2220),
#  ('haven', 2220),
#  ('british', 2220),
#  ('hot', 2220),
#  ('fake', 2214),
#  ('reading', 2214),
#  ('heart', 2214),
#  ('weird', 2208),
#  ('incredibly', 2208),
#  ('hear', 2208),
#  ('musical', 2202),
#  ('cop', 2202),
#  ('enjoyed', 2202),
#  ('hilarious', 2202),
#  ('message', 2196),
#  ('happy', 2196),
#  ('pay', 2196),
#  ('box', 2190),
#  ('laughs', 2190),
#  ('suspense', 2178),
#  ('sadly', 2178),
#  ('eye', 2172),
#  ('similar', 2166),
#  ('third', 2166),
#  ('named', 2166),
#  ('modern', 2160),
#  ('failed', 2154),
#  ('events', 2154),
#  ('question', 2148),
#  ('forget', 2148),
#  ('male', 2142),
#  ('finds', 2142),
#  ('perfect', 2136),
#  ('sister', 2130),
#  ('spent', 2130),
#  ('result', 2124),
#  ('feature', 2124),
#  ('girlfriend', 2118),
#  ('comment', 2118),
#  ('sexual', 2112),
#  ('richard', 2106),
#  ('neither', 2106),
#  ('attempts', 2106),
#  ('elements', 2100),
#  ('screenplay', 2100),
#  ('spoilers', 2094),
#  ('filmmakers', 2088),
#  ('brain', 2088),
#  ('showing', 2088),
#  ('christmas', 2082),
#  ('miss', 2082),
#  ('dr', 2082),
#  ('cover', 2070),
#  ('sequences', 2064),
#  ('red', 2064),
#  ('excuse', 2058),
#  ('typical', 2058),
#  ('crazy', 2052),
#  ('baby', 2052),
#  ('ideas', 2052),
#  ('loved', 2046),
#  ('meant', 2046),
#  ('fire', 2040),
#  ('worked', 2040),
#  ('follow', 2034),
#  ('unbelievable', 2034),
#  ('theme', 2022),
#  ('producers', 2016),
#  ('appear', 2016),
#  ('twist', 2016),
#  ('plus', 2016),
#  ('barely', 2016),
#  ('team', 2010),
#  ('directors', 2010),
#  ('viewers', 1998),
#  ('tom', 1992),
#  ('slasher', 1992),
#  ('leads', 1992),
#  ('villain', 1986),
#  ('wrote', 1986),
#  ('working', 1986),
#  ('gun', 1986),
#  ('realize', 1980),
#  ('strong', 1980),
#  ('open', 1980),
#  ('island', 1980),
#  ('quickly', 1974),
#  ('disappointing', 1974),
#  ('yeah', 1974),
#  ('positive', 1974),
#  ('release', 1968),
#  ('simple', 1968),
#  ('weren', 1968),
#  ('honestly', 1968),
#  ('tells', 1962),
#  ('kills', 1962),
#  ('doctor', 1962),
#  ('period', 1962),
#  ('eventually', 1962),
#  ('list', 1956),
#  ('acted', 1956),
#  ('nowhere', 1956),
#  ('dog', 1956),
#  ('herself', 1956),
#  ('walk', 1950),
#  ('air', 1944),
#  ('apart', 1944),
#  ('makers', 1938),
#  ('subject', 1938),
#  ('fi', 1932),
#  ('learn', 1932),
#  ('bother', 1914),
#  ('admit', 1914),
#  ('sci', 1914),
#  ('jack', 1908),
#  ('hands', 1908),
#  ('disappointment', 1908),
#  ('note', 1908),
#  ('value', 1902),
#  ('casting', 1902),
#  ('e', 1902),
#  ('certain', 1902),
#  ('peter', 1896),
#  ('grade', 1896),
#  ('missing', 1890),
#  ('suddenly', 1890),
#  ('previous', 1878),
#  ('stick', 1878),
#  ('form', 1878),
#  ('break', 1878),
#  ('soundtrack', 1872),
#  ('front', 1866),
#  ('expecting', 1866),
#  ('surprised', 1866),
#  ('parents', 1860),
#  ('relationship', 1860),
#  ('surprise', 1860),
#  ('today', 1854),
#  ('shoot', 1854),
#  ('leaves', 1848),
#  ('creepy', 1848),
#  ('vampire', 1848),
#  ('somewhere', 1848),
#  ('ways', 1848),
#  ('ended', 1848),
#  ('painful', 1848),
#  ('concept', 1848),
#  ('th', 1842),
#  ('spend', 1842),
#  ('fighting', 1836),
#  ('future', 1836),
#  ('effect', 1836),
#  ('difficult', 1836),
#  ('street', 1836),
#  ('america', 1830),
#  ('c', 1830),
#  ('accent', 1824),
#  ('project', 1812),
#  ('truth', 1812),
#  ('deal', 1806),
#  ('indeed', 1806),
#  ('f', 1806),
#  ('joe', 1806),
#  ('biggest', 1800),
#  ('rate', 1800),
#  ('paul', 1794),
#  ('japanese', 1794),
#  ('begins', 1788),
#  ('college', 1788),
#  ('utterly', 1788),
#  ('redeeming', 1788),
#  ('york', 1782),
#  ('disney', 1782),
#  ('fairly', 1782),
#  ('crew', 1776),
#  ('revenge', 1776),
#  ('cartoon', 1776),
#  ('create', 1776),
#  ('computer', 1770),
#  ('interested', 1770),
#  ('stage', 1770),
#  ('outside', 1770),
#  ('co', 1770),
#  ('among', 1764),
#  ('speak', 1764),
#  ('considering', 1764),
#  ('channel', 1758),
#  ('towards', 1758),
#  ('sick', 1758),
#  ('hair', 1752),
#  ('particular', 1752),
#  ('van', 1752),
#  ('cause', 1752),
#  ('talented', 1752),
#  ('bottom', 1746),
#  ('reasons', 1746),
#  ('telling', 1740),
#  ('mediocre', 1740),
#  ('cat', 1740),
#  ('supporting', 1734),
#  ('store', 1734),
#  ('waiting', 1728),
#  ('hoping', 1728),
#  ...]

# %% [markdown]
# As you can see, common words like "the" appear very often in both positive and negative reviews. Instead of finding the most common words in positive or negative reviews, what you really want are the words found in positive reviews more often than in negative reviews, and vice versa. To accomplish this, you'll need to calculate the **ratios** of word usage between positive and negative reviews.
#
# **TODO:** Check all the words you've seen and calculate the ratio of postive to negative uses and store that ratio in `pos_neg_ratios`.
# >Hint: the positive-to-negative ratio for a given word can be calculated with `positive_counts[word] / float(negative_counts[word]+1)`. Notice the `+1` in the denominator – that ensures we don't divide by zero for words that are only seen in positive reviews.

# %%
# Create Counter object to store positive/negative ratios
pos_neg_ratios = Counter()

# TODO: Calculate the ratios of positive and negative uses of the most common words
#       Consider words to be "common" if they've been used at least 100 times
for word, cnt in list(total_counts.most_common()):
    if (cnt > 100):
        pos_neg_ratios[word] = positive_counts[word] / float(negative_counts[word] + 1)

# %% [markdown]
# Examine the ratios you've calculated for a few words:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 1.0608047249154626
# Pos-to-neg ratio for 'amazing' = 4.03560076287349
# Pos-to-neg ratio for 'terrible' = 0.1775488199353061

# %% [markdown]
# Looking closely at the values you just calculated, we see the following:
#
# * Words that you would expect to see more often in positive reviews – like "amazing" – have a ratio greater than 1. The more skewed a word is toward postive, the farther from 1 its positive-to-negative ratio  will be.
# * Words that you would expect to see more often in negative reviews – like "terrible" – have positive values that are less than 1. The more skewed a word is toward negative, the closer to zero its positive-to-negative ratio will be.
# * Neutral words, which don't really convey any sentiment because you would expect to see them in all sorts of reviews – like "the" – have values very close to 1. A perfectly neutral word – one that was used in exactly the same number of positive reviews as negative reviews – would be almost exactly 1. The `+1` we suggested you add to the denominator slightly biases words toward negative, but it won't matter because it will be a tiny bias and later we'll be ignoring words that are too close to neutral anyway.
#
# Ok, the ratios tell us which words are used more often in postive or negative reviews, but the specific values we've calculated are a bit difficult to work with. A very positive word like "amazing" has a value above 4, whereas a very negative word like "terrible" has a value around 0.18. Those values aren't easy to compare for a couple of reasons:
#
# * Right now, 1 is considered neutral, but the absolute value of the positive-to-negative ratios of very positive words is larger than the absolute value of the ratios for the very negative words. So there is no way to directly compare two numbers and see if one word conveys the same magnitude of positive sentiment as another word conveys negative sentiment. So we should center all the values around netural so the absolute value fro neutral of the postive-to-negative ratio for a word would indicate how much sentiment (positive or negative) that word conveys.
# * When comparing absolute values it's easier to do that around zero than one.
#
# To fix these issues, we'll convert all of our ratios to new values using logarithms.
#
# **TODO:** Go through all the ratios you calculated and convert them to logarithms. (i.e. use `np.log(ratio)`)
#
# In the end, extremely positive and extremely negative words will have positive-to-negative ratios with similar magnitudes but opposite signs.

# %%
# TODO: Convert ratios to logs
for term, ratio in pos_neg_ratios.most_common():
    if (ratio != 0): 
        pos_neg_ratios[term] = np.log(ratio)

# %% [markdown]
# Examine the new ratios you've calculated for the same words from before:

# %%
print("Pos-to-neg ratio for 'the' = {}".format(pos_neg_ratios["the"]))
print("Pos-to-neg ratio for 'amazing' = {}".format(pos_neg_ratios["amazing"]))
print("Pos-to-neg ratio for 'terrible' = {}".format(pos_neg_ratios["terrible"]))
# Out:
# Pos-to-neg ratio for 'the' = 0.05902779454536978
# Pos-to-neg ratio for 'amazing' = 1.3951551785880218
# Pos-to-neg ratio for 'terrible' = -1.7285096659947043

# %% [markdown]
# If everything worked, now you should see neutral words with values close to zero. In this case, "the" is near zero but slightly positive, so it was probably used in more positive reviews than negative reviews. But look at "amazing"'s ratio - it's above `1`, showing it is clearly a word with positive sentiment. And "terrible" has a similar score, but in the opposite direction, so it's below `-1`. It's now clear that both of these words are associated with specific, opposing sentiments.
#
# Now run the following cells to see more ratios.
#
# The first cell displays all the words, ordered by how associated they are with postive reviews. (Your notebook will most likely truncate the output so you won't actually see *all* the words in the list.)
#
# The second cell displays the 30 words most associated with negative reviews by reversing the order of the first list and then looking at the first 30 words. (If you want the second cell to display all the words, ordered by how associated they are with negative reviews, you could just write `reversed(pos_neg_ratios.most_common())`.)
#
# You should continue to see values similar to the earlier ones we checked – neutral words will be close to `0`, words will get more positive as their ratios approach and go above `1`, and words will get more negative as their ratios approach and go below `-1`. That's why we decided to use the logs instead of the raw ratios.

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()
# Out:
# [('edie', 6.483107351457199),
#  ('antwone', 6.269096283706261),
#  ('din', 6.198478716492308),
#  ('gunga', 5.981414211254481),
#  ('goldsworthy', 5.966146739123692),
#  ('yokai', 5.886104031450156),
#  ('gypo', 5.886104031450156),
#  ('flavia', 5.723585101952381),
#  ('visconti', 5.723585101952381),
#  ('blandings', 5.662960480135946),
#  ('kells', 5.662960480135946),
#  ('brashear', 5.641907070938114),
#  ('gino', 5.62040086571715),
#  ('deathtrap', 5.598421958998375),
#  ('harilal', 5.5053315359323625),
#  ('panahi', 5.5053315359323625),
#  ('ossessione', 5.455321115357702),
#  ('tsui', 5.429345628954441),
#  ('caruso', 5.429345628954441),
#  ('sabu', 5.402677381872279),
#  ('ahmad', 5.402677381872279),
#  ('khouri', 5.375278407684165),
#  ('dominick', 5.375278407684165),
#  ('mj', 5.3471075307174685),
#  ('aweigh', 5.3471075307174685),
#  ('mcintire', 5.318119993844216),
#  ('kriemhild', 5.318119993844216),
#  ('newcombe', 5.288267030694535),
#  ('blackie', 5.288267030694535),
#  ('daisies', 5.288267030694535),
#  ('kei', 5.2574953720277815),
#  ('trelkovsky', 5.2574953720277815),
#  ('hilliard', 5.225746673713202),
#  ('jaffar', 5.225746673713202),
#  ('sheeta', 5.19295685089021),
#  ('pazu', 5.19295685089021),
#  ('offside', 5.19295685089021),
#  ('krell', 5.19295685089021),
#  ('bathsheba', 5.19295685089021),
#  ('fineman', 5.159055299214529),
#  ('venoms', 5.159055299214529),
#  ('ranma', 5.123963979403259),
#  ('paine', 5.123963979403259),
#  ('pimlico', 5.123963979403259),
#  ('ronny', 5.123963979403259),
#  ('abhay', 5.087596335232384),
#  ('kipling', 5.049856007249537),
#  ('pym', 5.049856007249537),
#  ('gabe', 5.0106352940962555),
#  ('audiard', 5.0106352940962555),
#  ('kelso', 5.0106352940962555),
#  ('scalise', 5.0106352940962555),
#  ('milverton', 5.0106352940962555),
#  ('mukhsin', 4.969813299576001),
#  ('xica', 4.969813299576001),
#  ('moonwalker', 4.969813299576001),
#  ('grisby', 4.969813299576001),
#  ('heaton', 4.927253685157205),
#  ('togar', 4.927253685157205),
#  ('chikatilo', 4.927253685157205),
#  ('jannings', 4.927253685157205),
#  ('soha', 4.882801922586371),
#  ('matuschek', 4.882801922586371),
#  ('fanfan', 4.882801922586371),
#  ('desdemona', 4.882801922586371),
#  ('miklos', 4.882801922586371),
#  ('leonora', 4.882801922586371),
#  ('matador', 4.882801922586371),
#  ('pidgeon', 4.882801922586371),
#  ('maradona', 4.836281906951478),
#  ('firemen', 4.836281906951478),
#  ('joss', 4.836281906951478),
#  ('bjm', 4.836281906951478),
#  ('microfilm', 4.836281906951478),
#  ('gauri', 4.836281906951478),
#  ('reda', 4.836281906951478),
#  ('coonskin', 4.787491742782046),
#  ('mcintyre', 4.787491742782046),
#  ('quibble', 4.787491742782046),
#  ('coe', 4.787491742782046),
#  ('prote', 4.787491742782046),
#  ('carrre', 4.787491742782046),
#  ('emory', 4.787491742782046),
#  ('siegfried', 4.787491742782046),
#  ('hillyer', 4.736198448394496),
#  ('pinjar', 4.736198448394496),
#  ('knockout', 4.736198448394496),
#  ('schlesinger', 4.736198448394496),
#  ('pakeezah', 4.736198448394496),
#  ('rvd', 4.736198448394496),
#  ('ackland', 4.736198448394496),
#  ('burakov', 4.736198448394496),
#  ('flippen', 4.736198448394496),
#  ('ferdie', 4.736198448394496),
#  ('petiot', 4.736198448394496),
#  ('malfique', 4.736198448394496),
#  ('baloo', 4.736198448394496),
#  ('magnus', 4.736198448394496),
#  ('digicorp', 4.736198448394496),
#  ('versatility', 4.736198448394496),
#  ('railly', 4.736198448394496),
#  ('falco', 4.68213122712422),
#  ('pappas', 4.68213122712422),
#  ('burgade', 4.68213122712422),
#  ('lando', 4.68213122712422),
#  ('hoechlin', 4.68213122712422),
#  ('guerrero', 4.68213122712422),
#  ('iphigenia', 4.68213122712422),
#  ('iek', 4.68213122712422),
#  ('volckman', 4.68213122712422),
#  ('geer', 4.68213122712422),
#  ('pollak', 4.68213122712422),
#  ('hobson', 4.68213122712422),
#  ('beckett', 4.624972813284271),
#  ('hewlett', 4.624972813284271),
#  ('nagra', 4.624972813284271),
#  ('toughness', 4.624972813284271),
#  ('cdric', 4.624972813284271),
#  ('jacknife', 4.624972813284271),
#  ('kralik', 4.624972813284271),
#  ('naudet', 4.624972813284271),
#  ('peralta', 4.624972813284271),
#  ('nighy', 4.624972813284271),
#  ('jeon', 4.624972813284271),
#  ('orked', 4.624972813284271),
#  ('paulie', 4.616533944638406),
#  ('iturbi', 3.8161412337248635),
#  ('gundam', 3.7485986888155587),
#  ('feinstone', 3.7170503310806327),
#  ('giovanna', 3.7170503310806327),
#  ('luzhin', 3.6525118099430616),
#  ('philo', 3.607049435866304),
#  ('lindy', 3.58351893845611),
#  ('clutter', 3.5094109663023882),
#  ('anchors', 3.4834354798991276),
#  ('korda', 3.4011973816621555),
#  ('callahan', 3.372209844788903),
#  ('aiello', 3.3423568816392217),
#  ('capote', 3.3376839759398296),
#  ('felix', 3.3350575791576103),
#  ('excellently', 3.3043475556722375),
#  ('bake', 3.279836524657888),
#  ('deanna', 3.2521618025016674),
#  ('hayworth', 3.2521618025016674),
#  ('hickock', 3.247046701834897),
#  ('eustache', 3.247046701834897),
#  ('ashraf', 3.247046701834897),
#  ('aviv', 3.247046701834897),
#  ('fido', 3.2417696447340534),
#  ('dench', 3.2131451501592156),
#  ('conroy', 3.2131451501592156),
#  ('partition', 3.2131451501592156),
#  ('beery', 3.2131451501592156),
#  ('vance', 3.1780538303479458),
#  ('sammo', 3.1780538303479458),
#  ('pang', 3.1780538303479458),
#  ('kolchak', 3.1648086035979253),
#  ('laputa', 3.158635744490844),
#  ('emil', 3.1416861861770706),
#  ('katsu', 3.1416861861770706),
#  ('dev', 3.1416861861770706),
#  ('fricker', 3.1416861861770706),
#  ('saura', 3.1039458581942236),
#  ('gackt', 3.076957713476577),
#  ('myrtle', 3.076957713476577),
#  ('adele', 3.076957713476577),
#  ('sox', 3.066828195237721),
#  ('alvin', 3.052013109452581),
#  ('bernsen', 3.033472601536838),
#  ('gannon', 3.033472601536838),
#  ('blackadder', 3.0239031505206873),
#  ('perdition', 3.0239031505206873),
#  ('yuzna', 3.0239031505206873),
#  ('unpretentious', 3.0239031505206873),
#  ('binder', 3.0239031505206873),
#  ('lupino', 3.0239031505206873),
#  ('biko', 3.0155349008501706),
#  ('mathieu', 3.006203573421286),
#  ('mcnally', 2.9813435361018916),
#  ('mahatma', 2.9813435361018916),
#  ('godmother', 2.9813435361018916),
#  ('jonestown', 2.9813435361018916),
#  ('abbey', 2.9813435361018916),
#  ('judi', 2.9813435361018916),
#  ('polanski', 2.972892781584168),
#  ('gilliam', 2.9581943542349256),
#  ('waterman', 2.9368917735310576),
#  ('pike', 2.9368917735310576),
#  ('stockwell', 2.9368917735310576),
#  ('noriko', 2.9368917735310576),
#  ('woronov', 2.9368917735310576),
#  ('radiant', 2.9368917735310576),
#  ('matthau', 2.9038854770628877),
#  ('reservations', 2.8903717578961645),
#  ('schmid', 2.8903717578961645),
#  ('johnston', 2.8903717578961645),
#  ('marylee', 2.8903717578961645),
#  ('brisson', 2.8903717578961645),
#  ('oberon', 2.8903717578961645),
#  ('harriet', 2.872672180796764),
#  ('warhols', 2.8643962714929043),
#  ('abu', 2.8643962714929043),
#  ('sammi', 2.8643962714929043),
#  ('zu', 2.8643962714929043),
#  ('chavez', 2.8495497633759097),
#  ('montrose', 2.841581593726733),
#  ('ungar', 2.841581593726733),
#  ('homeward', 2.841581593726733),
#  ('jud', 2.841581593726733),
#  ('bannister', 2.841581593726733),
#  ('girlfight', 2.841581593726733),
#  ('hundstage', 2.841581593726733),
#  ('manny', 2.841581593726733),
#  ('rosenstrasse', 2.8377280244107426),
#  ('ultimatum', 2.836304536625889),
#  ('ratso', 2.8355635214011694),
#  ('mccartney', 2.790288299339182),
#  ('tully', 2.790288299339182),
#  ('linklater', 2.790288299339182),
#  ('elia', 2.790288299339182),
#  ('hickok', 2.790288299339182),
#  ('gigi', 2.790288299339182),
#  ('sweetly', 2.790288299339182),
#  ('aborigines', 2.790288299339182),
#  ('zentropa', 2.790288299339182),
#  ('taker', 2.7821581732559317),
#  ('delightfully', 2.7593434954897607),
#  ('durbin', 2.75317063638268),
#  ('creasy', 2.739140788172241),
#  ('victoria', 2.7381799425542392),
#  ('quartier', 2.7362210780689065),
#  ('hatcher', 2.7362210780689065),
#  ('treasured', 2.7362210780689065),
#  ('squire', 2.7362210780689065),
#  ('corbett', 2.731766727719526),
#  ('mclaglen', 2.7144810914325004),
#  ('mildred', 2.7126905806587125),
#  ('vonnegut', 2.697468091771673),
#  ('pita', 2.6925460145662448),
#  ('braveheart', 2.6837575085331657),
#  ('kennel', 2.6790626642289577),
#  ('brodie', 2.6790626642289577),
#  ('cartwright', 2.6790626642289577),
#  ('speakeasy', 2.6790626642289577),
#  ('sailing', 2.6790626642289577),
#  ('pressburger', 2.6790626642289577),
#  ('leung', 2.6790626642289577),
#  ('anand', 2.6790626642289577),
#  ('curr', 2.6790626642289577),
#  ('mahoney', 2.6790626642289577),
#  ('spellbinding', 2.6790626642289577),
#  ('province', 2.6790626642289577),
#  ('natali', 2.6759618865507098),
#  ('kazan', 2.667228206581955),
#  ('sirk', 2.6467496752384143),
#  ('gandhi', 2.6361376195119237),
#  ('flamenco', 2.6280074934286737),
#  ('tigerland', 2.6280074934286737),
#  ('genesis', 2.618438042412523),
#  ('boothe', 2.618438042412523),
#  ('braun', 2.618438042412523),
#  ('janeway', 2.618438042412523),
#  ('lupin', 2.618438042412523),
#  ('yang', 2.618438042412523),
#  ('tackled', 2.618438042412523),
#  ('mores', 2.618438042412523),
#  ('loomis', 2.618438042412523),
#  ('mccoy', 2.6062675067922676),
#  ('cheadle', 2.5982353350950036),
#  ('aunts', 2.5941059417529924),
#  ('sullavan', 2.5941059417529924),
#  ('olympia', 2.5941059417529924),
#  ('elsa', 2.5849901083449827),
#  ('othello', 2.5752907112562693),
#  ('novak', 2.5628681912577123),
#  ('jabba', 2.560892556765922),
#  ('tomlinson', 2.559014621941722),
#  ('cal', 2.543175557911976),
#  ('flawless', 2.5380164751019487),
#  ('coop', 2.536199944175551),
#  ('christy', 2.5303690238647576),
#  ('fuller', 2.5246469784375143),
#  ('ramones', 2.5246469784375143),
#  ('magnificently', 2.5226469777708473),
#  ('benet', 2.5226469777708473),
#  ('raoul', 2.5226469777708473),
#  ('complement', 2.5226469777708473),
#  ('fagin', 2.510882136191261),
#  ('hanzo', 2.510882136191261),
#  ('beetle', 2.4849066497880004),
#  ('colman', 2.4849066497880004),
#  ('weir', 2.4849066497880004),
#  ('marvelously', 2.4849066497880004),
#  ('haines', 2.4849066497880004),
#  ('winchester', 2.4849066497880004),
#  ('rea', 2.4849066497880004),
#  ('iris', 2.4849066497880004),
#  ('chamberlain', 2.46864612891622),
#  ('kalifornia', 2.458238402705839),
#  ('influential', 2.458238402705839),
#  ('wodehouse', 2.445685936634719),
#  ('vertigo', 2.4308394285177246),
#  ('northam', 2.423031246069913),
#  ('iago', 2.404863942114464),
#  ('romy', 2.404863942114464),
#  ('footlight', 2.404863942114464),
#  ('fez', 2.404863942114464),
#  ('abbot', 2.404863942114464),
#  ('devos', 2.404863942114464),
#  ('stevenson', 2.402668551551028),
#  ('cheung', 2.402668551551028),
#  ('finely', 2.402668551551028),
#  ('stardust', 2.401525040848949),
#  ('carla', 2.3872681802240843),
#  ('sabrina', 2.3743647753881763),
#  ('celine', 2.373681014677776),
#  ('kinnear', 2.3651054499753794),
#  ('quotable', 2.362304327695668),
#  ('duchess', 2.362304327695668),
#  ('curtiz', 2.362304327695668),
#  ('tintin', 2.362304327695668),
#  ('peters', 2.3612926938208236),
#  ('tenant', 2.355228826479468),
#  ('hark', 2.343828051528095),
#  ('marjorie', 2.343828051528095),
#  ('vulnerability', 2.343828051528095),
#  ('darius', 2.343828051528095),
#  ('enchanting', 2.334083760053417),
#  ('superbly', 2.331998978200339),
#  ('egan', 2.3178525651248343),
#  ('pawn', 2.3178525651248343),
#  ('bozz', 2.3178525651248343),
#  ('frailty', 2.3178525651248343),
#  ('pickpocket', 2.3178525651248343),
#  ('benoit', 2.3130563928613412),
#  ('duryea', 2.3130563928613412),
#  ('pecker', 2.3105532626432224),
#  ('raines', 2.307225472550548),
#  ('georges', 2.2917154207571415),
#  ('devotion', 2.286455711064162),
#  ('ella', 2.2813076945467605),
#  ('fairytale', 2.2813076945467605),
#  ('askey', 2.2813076945467605),
#  ('tel', 2.2813076945467605),
#  ('stairway', 2.2713325494899412),
#  ('bafta', 2.2713325494899412),
#  ('strathairn', 2.2713325494899412),
#  ('francois', 2.2713325494899412),
#  ('ida', 2.2713325494899412),
#  ('refreshingly', 2.2713325494899412),
#  ('oshii', 2.2713325494899412),
#  ('trier', 2.2583790004895503),
#  ('rukh', 2.25664799780702),
#  ('blaine', 2.2485178717237697),
#  ('cheech', 2.2364452904895007),
#  ('dixon', 2.2270775404859005),
#  ('finlay', 2.222542385320509),
#  ('sumptuous', 2.222542385320509),
#  ('firefighters', 2.222542385320509),
#  ('bhandarkar', 2.222542385320509),
#  ('skagway', 2.222542385320509),
#  ('exquisitely', 2.222542385320509),
#  ('pabst', 2.222542385320509),
#  ('miyazaki', 2.217427284653739),
#  ('perfection', 2.216642663193321),
#  ('venezuela', 2.2146163200480884),
#  ('astaire', 2.201435109872563),
#  ('edith', 2.1864136612320038),
#  ('clarence', 2.1838015570040787),
#  ('transcends', 2.1795250002368185),
#  ('wtc', 2.1795250002368185),
#  ('singin', 2.1795250002368185),
#  ('rathbone', 2.1795250002368185),
#  ('malone', 2.176605290133484),
#  ('splendidly', 2.171249090932959),
#  ('uncompromising', 2.171249090932959),
#  ('hardwicke', 2.171249090932959),
#  ('electrifying', 2.171249090932959),
#  ('siu', 2.171249090932959),
#  ('teri', 2.171249090932959),
#  ('twisty', 2.171249090932959),
#  ('prix', 2.171249090932959),
#  ('mol', 2.1576937385795842),
#  ('turturro', 2.143157356065944),
#  ('adelaide', 2.143157356065944),
#  ('lighten', 2.143157356065944),
#  ('pickford', 2.141433217707804),
#  ('scoop', 2.141433217707804),
#  ('zorro', 2.1320852751652577),
#  ('enthralling', 2.128231705849268),
#  ('mostel', 2.128231705849268),
#  ('henderson', 2.128231705849268),
#  ('undying', 2.117181869662683),
#  ('celebrates', 2.117181869662683),
#  ('talespin', 2.117181869662683),
#  ('examines', 2.117181869662683),
#  ('champions', 2.117181869662683),
#  ('raja', 2.117181869662683),
#  ('trotta', 2.117181869662683),
#  ('robust', 2.117181869662683),
#  ('prem', 2.117181869662683),
#  ('franks', 2.117181869662683),
#  ('mower', 2.117181869662683),
#  ('dandy', 2.1080967974402123),
#  ('superlative', 2.105417028083097),
#  ('labyrinth', 2.105417028083097),
#  ('lila', 2.0992441689760155),
#  ('corbin', 2.0992441689760155),
#  ('voight', 2.096419878214254),
#  ('heartbreaking', 2.0895939131438537),
#  ('captures', 2.0725210988352623),
#  ('chang', 2.0693912058263346),
#  ('booker', 2.0693912058263346),
#  ('mendes', 2.0661963149298153),
#  ('brock', 2.0661963149298153),
#  ('morbius', 2.0661963149298153),
#  ('abby', 2.0661963149298153),
#  ('zelda', 2.0661963149298153),
#  ('guiness', 2.0661963149298153),
#  ('wang', 2.0610924030116395),
#  ('kovacs', 2.0600234558227344),
#  ('vulcan', 2.0600234558227344),
#  ('bureaucracy', 2.0600234558227344),
#  ('stepsisters', 2.0600234558227344),
#  ('provo', 2.0600234558227344),
#  ('axel', 2.0600234558227344),
#  ('ullman', 2.0600234558227344),
#  ('hoon', 2.0600234558227344),
#  ('ilona', 2.0600234558227344),
#  ('entranced', 2.0600234558227344),
#  ('caprice', 2.0600234558227344),
#  ('radium', 2.0600234558227344),
#  ('custer', 2.0600234558227344),
#  ('carrell', 2.0600234558227344),
#  ('silhouette', 2.0600234558227344),
#  ('deft', 2.0600234558227344),
#  ('dell', 2.0600234558227344),
#  ('shefali', 2.0600234558227344),
#  ('truman', 2.0559110442696418),
#  ('sunrise', 2.0520425674917218),
#  ('wonderfully', 2.0440699135275575),
#  ('sematary', 2.038619547159581),
#  ('sg', 2.0378925387669637),
#  ('masterson', 2.0378925387669637),
#  ('hawke', 2.032921526044943),
#  ('strangler', 2.02537432040956),
#  ('shemp', 2.02537432040956),
#  ('rory', 2.02537432040956),
#  ('culp', 2.02537432040956),
#  ('parisian', 2.02537432040956),
#  ('masterful', 2.0246910269084277),
#  ('busby', 2.0213339108725554),
#  ('holt', 2.0213339108725554),
#  ('informer', 2.0213339108725554),
#  ('expertly', 2.019543400098767),
#  ('powell', 2.01092159524308),
#  ('tomei', 2.0094829530729257),
#  ('brosnan', 2.0082877814235456),
#  ('batwoman', 2.0068708488450007),
#  ('keeler', 2.0068708488450007),
#  ('connolly', 2.0068708488450007),
#  ('carface', 2.0068708488450007),
#  ('zabriskie', 2.0068708488450007),
#  ('jerome', 1.9993988340062996),
#  ('crashers', 1.9993988340062996),
#  ('bulldog', 1.9993988340062996),
#  ('scola', 1.9993988340062996),
#  ('textile', 1.9993988340062996),
#  ('caleb', 1.9993988340062996),
#  ('krabbe', 1.9993988340062996),
#  ('romanticized', 1.9993988340062996),
#  ('schmidt', 1.9993988340062996),
#  ('sceptical', 1.9993988340062996),
#  ('petition', 1.9993988340062996),
#  ('muller', 1.9993988340062996),
#  ('doodlebops', 1.9993988340062996),
#  ('mvp', 1.9993988340062996),
#  ('janice', 1.9993988340062996),
#  ('europa', 1.9942837333395291),
#  ('greene', 1.9875040463541502),
#  ('todesking', 1.9828147059907644),
#  ('miners', 1.9828147059907644),
#  ('reginald', 1.9828147059907644),
#  ('cypher', 1.9818030721159199),
#  ('crouse', 1.9740810260220096),
#  ('leia', 1.9740810260220096),
#  ('witherspoon', 1.9740810260220096),
#  ('darren', 1.971345046203135),
#  ('lily', 1.9706386818310369),
#  ('vincenzo', 1.9686901773871333),
#  ('pegg', 1.9623849862588183),
#  ('bakshi', 1.9532469391191676),
#  ('precise', 1.942041672277393),
#  ('parrot', 1.942041672277393),
#  ('marcus', 1.9412912031990188),
#  ('friendships', 1.9401794743463283),
#  ('foch', 1.9401794743463283),
#  ('maclean', 1.9401794743463283),
#  ('delon', 1.9383629434199305),
#  ('mastery', 1.9383629434199305),
#  ('poirot', 1.9383629434199305),
#  ('extravagant', 1.9383629434199305),
#  ('connecticut', 1.9383629434199305),
#  ('buttgereit', 1.9383629434199305),
#  ('lincoln', 1.9383629434199305),
#  ('criterion', 1.9383629434199305),
#  ('doolittle', 1.9383629434199305),
#  ('civilized', 1.9383629434199305),
#  ('partnership', 1.9383629434199305),
#  ('mammoth', 1.9348603128687283),
#  ('perceptive', 1.9348603128687283),
#  ('weber', 1.9348603128687283),
#  ('henri', 1.9348603128687283),
#  ('dahlia', 1.9348603128687283),
#  ('hoodlums', 1.9348603128687283),
#  ('advancing', 1.9348603128687283),
#  ('paxinou', 1.9348603128687283),
#  ('blier', 1.9348603128687283),
#  ('pendleton', 1.9348603128687283),
#  ('lanchester', 1.9348603128687283),
#  ('everytown', 1.9348603128687283),
#  ('candid', 1.9348603128687283),
#  ('airwolf', 1.9348603128687283),
#  ('tsing', 1.9348603128687283),
#  ('carell', 1.9308722716907727),
#  ('montana', 1.9201406358762618),
#  ('massey', 1.9185111748671988),
#  ('evans', 1.9185111748671988),
#  ('apartheid', 1.9131203262323224),
#  ('paperhouse', 1.9050881545350582),
#  ('walsh', 1.9045549633733994),
#  ('lemmon', 1.9029851043382795),
#  ('explores', 1.8953001481688954),
#  ('steele', 1.8953001481688954),
#  ('meatball', 1.8918429277850375),
#  ('shia', 1.8918429277850375),
#  ('accustomed', 1.8918429277850375),
#  ('palsy', 1.8918429277850375),
#  ('hermann', 1.8918429277850375),
#  ('proposes', 1.8918429277850375),
#  ('refreshing', 1.8853950742620478),
#  ('breathtaking', 1.8850169627146378),
#  ('scorpion', 1.8841327893590702),
#  ('bourne', 1.8804251063137114),
#  ('bittersweet', 1.8697210106977669),
#  ('cedric', 1.8697210106977669),
#  ('weaves', 1.8687205103641833),
#  ('bagdad', 1.8687205103641833),
#  ('yoda', 1.8687205103641833),
#  ('holm', 1.8687205103641833),
#  ('deliciously', 1.8592007500235876),
#  ('ira', 1.8592007500235876),
#  ('dukakis', 1.854279826209389),
#  ('moonstruck', 1.854279826209389),
#  ('celeste', 1.854279826209389),
#  ('dickinson', 1.854279826209389),
#  ('myrna', 1.8444032027134771),
#  ('quintessential', 1.8444032027134771),
#  ('chico', 1.8430527636156055),
#  ('repulsion', 1.8430527636156055),
#  ('jonny', 1.8430527636156055),
#  ('unavailable', 1.8430527636156055),
#  ('ringo', 1.8430527636156055),
#  ('compliments', 1.8430527636156055),
#  ('antidote', 1.8430527636156055),
#  ('chess', 1.8411522245576315),
#  ('flynn', 1.8401560100899053),
#  ('maintained', 1.8309801823813363),
#  ('restoration', 1.8309801823813363),
#  ('tenderness', 1.8309801823813363),
#  ('joyous', 1.8309801823813363),
#  ('nicky', 1.8309801823813363),
#  ('homer', 1.8264450272159451),
#  ('affection', 1.8240203314462764),
#  ('delightful', 1.8218692706994255),
#  ('ealing', 1.8184277163102163),
#  ('han', 1.8184277163102163),
#  ('andrews', 1.8151068332250462),
#  ('soccer', 1.8150163313923224),
#  ('kidman', 1.8080199900998353),
#  ('lumet', 1.8034555089912463),
#  ('cruz', 1.791759469228055),
#  ('nina', 1.791759469228055),
#  ('corinne', 1.791759469228055),
#  ('companionship', 1.791759469228055),
#  ('moriarty', 1.791759469228055),
#  ('enforcer', 1.791759469228055),
#  ('cheryl', 1.791759469228055),
#  ('sergeants', 1.791759469228055),
#  ('amicus', 1.791759469228055),
#  ('zelah', 1.791759469228055),
#  ('seamlessly', 1.791759469228055),
#  ('swordplay', 1.791759469228055),
#  ('complexities', 1.791759469228055),
#  ('trading', 1.791759469228055),
#  ('franchot', 1.791759469228055),
#  ('sopranos', 1.791759469228055),
#  ('demme', 1.791759469228055),
#  ('determination', 1.791759469228055),
#  ('elvira', 1.7766076642074529),
#  ('beautifully', 1.7758016837894441),
#  ('paula', 1.7734103305598585),
#  ('deliverance', 1.7734103305598585),
#  ('wai', 1.7589696464050641),
#  ('rugged', 1.7589696464050641),
#  ('hedy', 1.7589696464050641),
#  ('reeve', 1.754718197547706),
#  ('gripping', 1.7534406049259184),
#  ('raul', 1.7509374747078),
#  ('ae', 1.750086772827487),
#  ('tierney', 1.7459499331967607),
#  ('marisa', 1.7441314202388005),
#  ('stadium', 1.7441314202388005),
#  ('underrated', 1.7432062438110643),
#  ('longs', 1.7376922479577792),
#  ('yuen', 1.7376922479577792),
#  ('una', 1.7376922479577792),
#  ('piggy', 1.7376922479577792),
#  ('settling', 1.7376922479577792),
#  ('illusions', 1.7376922479577792),
#  ('astor', 1.7376922479577792),
#  ('batista', 1.7376922479577792),
#  ('chu', 1.7376922479577792),
#  ('cate', 1.7376922479577792),
#  ('soylent', 1.7356700025770115),
#  ('gershwin', 1.7285805676065233),
#  ('alienate', 1.7250680947293828),
#  ('rainer', 1.7250680947293828),
#  ('technicolor', 1.7208077332557705),
#  ('superb', 1.7172749674181744),
#  ('kline', 1.7142012348821805),
#  ('sadness', 1.71090737259896),
#  ('connelly', 1.7083778602890038),
#  ('jaffe', 1.7083778602890038),
#  ('lyle', 1.7083778602890038),
#  ('delight', 1.7053748550292342),
#  ('conductor', 1.694120999664139),
#  ('liza', 1.6899767749181127),
#  ('merrill', 1.6899767749181127),
#  ('diver', 1.6899767749181127),
#  ('regal', 1.6899767749181127),
#  ('welles', 1.6887602297559086),
#  ('macgregor', 1.6805338341178306),
#  ('rouge', 1.6805338341178306),
#  ('spall', 1.6805338341178306),
#  ('michell', 1.6805338341178306),
#  ('affectionate', 1.6805338341178306),
#  ('jafar', 1.6805338341178306),
#  ('wei', 1.6805338341178306),
#  ('lan', 1.6805338341178306),
#  ('jos', 1.6805338341178306),
#  ('dustin', 1.6762465821062107),
#  ('timeless', 1.6718001541490761),
#  ('macy', 1.67139578697818),
#  ('kurosawa', 1.6708068588103924),
#  ('liu', 1.6698696516190181),
#  ('clara', 1.6698696516190181),
#  ('einstein', 1.6698696516190181),
#  ('scarlett', 1.6681455132608782),
#  ('eagle', 1.6681455132608782),
#  ('layered', 1.6681455132608782),
#  ('grayson', 1.6665963262740489),
#  ('fateful', 1.6639260977181702),
#  ('trey', 1.6639260977181702),
#  ('akira', 1.6639260977181702),
#  ('humane', 1.6639260977181702),
#  ('sinatra', 1.660050123873477),
#  ('hartley', 1.6596997472149886),
#  ('realist', 1.6536091307472378),
#  ('mischievous', 1.6536091307472378),
#  ('planets', 1.6536091307472378),
#  ('albums', 1.6536091307472378),
#  ('sweetheart', 1.6536091307472378),
#  ('poppins', 1.6536091307472378),
#  ('nielsen', 1.6536091307472378),
#  ('unforgettable', 1.6530760816941044),
#  ('mesmerizing', 1.6511775186068656),
#  ('touching', 1.649023989128165),
#  ('maturity', 1.6465774593835572),
#  ('gently', 1.6465774593835572),
#  ('showcases', 1.6465774593835572),
#  ('conflicted', 1.6465774593835572),
#  ('favorites', 1.6431184452117664),
#  ('shanghai', 1.6418193219371402),
#  ('captivated', 1.6414772661787171),
#  ('relaxed', 1.6414772661787171),
#  ('fritz', 1.6414772661787171),
#  ('extraordinary', 1.638594496725556),
#  ('johansson', 1.6376087894007967),
#  ('iran', 1.6376087894007967),
#  ('delirious', 1.6376087894007967),
#  ('sullivan', 1.6358246676072954),
#  ('fairbanks', 1.6345738857056427),
#  ('wrenching', 1.6321293236361711),
#  ('heartwarming', 1.630118117671639),
#  ('stewart', 1.6227399751271867),
#  ('gaelic', 1.6199092123013956),
#  ('angelopoulos', 1.6199092123013956),
#  ('detractors', 1.6199092123013956),
#  ('teal', 1.6199092123013956),
#  ('dingo', 1.6199092123013956),
#  ('teaming', 1.6199092123013956),
#  ('chocolat', 1.6199092123013956),
#  ('streetcar', 1.6199092123013956),
#  ('doodle', 1.6199092123013956),
#  ('hitokiri', 1.6199092123013956),
#  ('sloth', 1.6199092123013956),
#  ('mononoke', 1.6199092123013956),
#  ('riots', 1.6199092123013956),
#  ('eskimo', 1.6199092123013956),
#  ('sharma', 1.6199092123013956),
#  ('affluent', 1.6174060820832772),
#  ('wickedly', 1.6174060820832772),
#  ('tragedies', 1.6174060820832772),
#  ('evolves', 1.6174060820832772),
#  ('outlaws', 1.6174060820832772),
#  ('illinois', 1.6174060820832772),
#  ('adversity', 1.6174060820832772),
#  ('denholm', 1.6174060820832772),
#  ('coen', 1.6158688027643908),
#  ('postman', 1.6158688027643908),
#  ('sherry', 1.6158688027643908),
#  ('irs', 1.6158688027643908),
#  ('blends', 1.6158688027643908),
#  ('celie', 1.6158688027643908),
#  ('gertrude', 1.6158688027643908),
#  ('brilliantly', 1.6150899258654468),
#  ('cloth', 1.6148287610689769),
#  ('blondell', 1.6140782919906025),
#  ('crowe', 1.6140782919906025),
#  ('gretchen', 1.6140782919906025),
#  ('dictator', 1.6140782919906025),
#  ('rowlands', 1.613067680484679),
#  ('lang', 1.613067680484679),
#  ('election', 1.6124185405722382),
#  ('watson', 1.611788089779054),
#  ('palma', 1.6002212573291763),
#  ('understated', 1.5983880762475153),
#  ('simmons', 1.5976034547870976),
#  ('elliott', 1.5910887737659039),
#  ('shahid', 1.5888186252313647),
#  ('diego', 1.5888186252313647),
#  ('cena', 1.5888186252313647),
#  ('benefits', 1.5888186252313647),
#  ('friendship', 1.5849182952597818),
#  ('climate', 1.5820389382459858),
#  ('metropolis', 1.5820389382459858),
#  ('maguire', 1.5820389382459858),
#  ('conveys', 1.5788374719853833),
#  ('thaw', 1.5766480896111095),
#  ('alain', 1.5766480896111095),
#  ('caf', 1.5766480896111095),
#  ('infectious', 1.5766480896111095),
#  ('formidable', 1.5766480896111095),
#  ('ritter', 1.5757844073924578),
#  ('loy', 1.5727059031653703),
#  ('incorporated', 1.5686159179138452),
#  ('flawlessly', 1.5686159179138452),
#  ('burtynsky', 1.5686159179138452),
#  ('intolerance', 1.5686159179138452),
#  ('nathan', 1.5686159179138452),
#  ('veronika', 1.5686159179138452),
#  ('staden', 1.5686159179138452),
#  ('neve', 1.5686159179138452),
#  ('buffalo', 1.5686159179138452),
#  ('testimony', 1.5686159179138452),
#  ('boman', 1.5686159179138452),
#  ('luminous', 1.5686159179138452),
#  ('wonderful', 1.56745041661641),
#  ('magnificent', 1.564919056032519),
#  ('jackie', 1.5644579077651815),
#  ('finest', 1.5634120900388182),
#  ('scrooge', 1.560853912578356),
#  ('irving', 1.5569198781506541),
#  ('pickup', 1.5569198781506541),
#  ('cecilia', 1.5553706911638245),
#  ('matured', 1.5553706911638245),
#  ('gras', 1.5553706911638245),
#  ('objections', 1.5553706911638245),
#  ('journeys', 1.5553706911638245),
#  ('furlong', 1.5553706911638245),
#  ('vidor', 1.5553706911638245),
#  ('broader', 1.5553706911638245),
#  ('siodmak', 1.5553706911638245),
#  ('frazetta', 1.5553706911638245),
#  ('labeouf', 1.5553706911638245),
#  ('mardi', 1.5553706911638245),
#  ('bravura', 1.5553706911638245),
#  ('mcconaughey', 1.5553706911638245),
#  ('triads', 1.5553706911638245),
#  ('pinkett', 1.5553706911638245),
#  ('tremendous', 1.5553706911638245),
#  ('exhibited', 1.5553706911638245),
#  ('scanners', 1.5553706911638245),
#  ('rubble', 1.5553706911638245),
#  ('odyssey', 1.5520866159626348),
#  ('heartfelt', 1.5494460018061251),
#  ('spock', 1.5477818310110032),
#  ('sondra', 1.5456263996891464),
#  ('riff', 1.5375253308438142),
#  ('tung', 1.5358260950908544),
#  ('aplomb', 1.5358260950908544),
#  ('palpable', 1.5358260950908544),
#  ('gomez', 1.5358260950908544),
#  ('dripped', 1.5358260950908544),
#  ('powerfully', 1.5358260950908544),
#  ('eroticism', 1.5358260950908544),
#  ('longing', 1.5310332067648025),
#  ('cunningham', 1.5310332067648025),
#  ('absorbing', 1.5310332067648025),
#  ('sidewalk', 1.5310332067648025),
#  ('freedom', 1.5282362322530096),
#  ('floriane', 1.5270669150009728),
#  ('daria', 1.5270669150009728),
#  ('ewoks', 1.5270669150009728),
#  ('delicate', 1.526651718814813),
#  ('hyde', 1.5264783334654406),
#  ('mann', 1.5263831542905724),
#  ('pleasantly', 1.5263831542905724),
#  ('stack', 1.5234954826333755),
#  ('astonishing', 1.5234954826333755),
#  ('andre', 1.5234954826333755),
#  ('jose', 1.5220959022789524),
#  ('soprano', 1.5220959022789524),
#  ('sidney', 1.5195018671019058),
#  ('jedi', 1.5188924825614147),
#  ('brisk', 1.5173226235262947),
#  ('exuberant', 1.5173226235262947),
#  ('darlene', 1.5173226235262947),
#  ('clair', 1.5173226235262947),
#  ('resentment', 1.5173226235262947),
#  ('balancing', 1.5173226235262947),
#  ('sharply', 1.5173226235262947),
#  ('deceit', 1.5173226235262947),
#  ('sweets', 1.5173226235262947),
#  ('duet', 1.5173226235262947),
#  ('shakti', 1.5173226235262947),
#  ('heavyweight', 1.5173226235262947),
#  ('kitty', 1.5166561789831343),
#  ('terrific', 1.5132744902571915),
#  ('gardens', 1.5130460667590344),
#  ('enhances', 1.5130460667590344),
#  ('hare', 1.5130460667590344),
#  ('fantastic', 1.5106070915726069),
#  ('hadley', 1.5095270015438387),
#  ('nancy', 1.508117806313279),
#  ('noir', 1.5048065254997902),
#  ('marvelous', 1.5021708185056923),
#  ('outstanding', 1.5018868153964553),
#  ('marie', 1.5004607563060854),
#  ('stargate', 1.5004076678873117),
#  ('fontaine', 1.499849060666753),
#  ('sassy', 1.499849060666753),
#  ('detract', 1.499089855265235),
#  ('iranian', 1.497998350699892),
#  ('ruth', 1.4965301911408913),
#  ('sorrow', 1.4962952563342191),
#  ('gen', 1.4962952563342191),
#  ('rousing', 1.4962952563342191),
#  ('berenger', 1.4962952563342191),
#  ('entertains', 1.4962952563342191),
#  ('stitches', 1.4932664806720584),
#  ('buscemi', 1.4932664806720584),
#  ('dignified', 1.4932664806720584),
#  ('gyllenhaal', 1.4932664806720584),
#  ('layers', 1.4902840746439383),
#  ('demille', 1.4875480948250634),
#  ('jacques', 1.4875480948250634),
#  ('gielgud', 1.4875480948250634),
#  ('idiosyncratic', 1.4863778196768733),
#  ('tyranny', 1.4863778196768733),
#  ('comeuppance', 1.4863778196768733),
#  ('exiled', 1.4863778196768733),
#  ('helmer', 1.4863778196768733),
#  ('projector', 1.4863778196768733),
#  ('kasdan', 1.4863778196768733),
#  ('diminish', 1.4863778196768733),
#  ('editions', 1.4863778196768733),
#  ('purity', 1.4863778196768733),
#  ('hobbits', 1.4863778196768733),
#  ('barriers', 1.4863778196768733),
#  ('lorne', 1.4863778196768733),
#  ('dyan', 1.4863778196768733),
#  ('retrospective', 1.4863778196768733),
#  ('exhibition', 1.4863778196768733),
#  ('solace', 1.4863778196768733),
#  ('sparring', 1.4863778196768733),
#  ('winkler', 1.4863778196768733),
#  ('piscopo', 1.4863778196768733),
#  ('denny', 1.4863778196768733),
#  ('otis', 1.4863778196768733),
#  ('marin', 1.4863778196768733),
#  ('tore', 1.4863778196768733),
#  ('drafted', 1.4863778196768733),
#  ('dunk', 1.4863778196768733),
#  ('hitchcockian', 1.4863778196768733),
#  ('musically', 1.4863778196768733),
#  ('jacobi', 1.4863778196768733),
#  ('wistful', 1.4863778196768733),
#  ('melbourne', 1.4834581095735382),
#  ('espionage', 1.4834581095735382),
#  ('taut', 1.4834581095735382),
#  ('sheridan', 1.4834581095735382),
#  ('affecting', 1.4834581095735382),
#  ('melancholy', 1.4834581095735382),
#  ('macarthur', 1.482438221672793),
#  ('definitive', 1.4788871479477155),
#  ('surpasses', 1.4766784225881595),
#  ('drifter', 1.4766784225881595),
#  ('leopold', 1.4766784225881595),
#  ('superiors', 1.4766784225881595),
#  ('marquis', 1.4766784225881595),
#  ('stark', 1.4762425977828302),
#  ('dismiss', 1.4733057381095203),
#  ('stanwyck', 1.468459761163381),
#  ('excellent', 1.46689839353452),
#  ('denis', 1.4653628845955837),
#  ('vienna', 1.4645465580196388),
#  ('mulligan', 1.463255402256019),
#  ('sparkling', 1.463255402256019),
#  ('theresa', 1.463255402256019),
#  ('widmark', 1.463255402256019),
#  ('aragorn', 1.463255402256019),
#  ('canoe', 1.463255402256019),
#  ('adjust', 1.463255402256019),
#  ('monarch', 1.463255402256019),
#  ('overhead', 1.463255402256019),
#  ('nobility', 1.463255402256019),
#  ('terrifically', 1.463255402256019),
#  ('ethereal', 1.463255402256019),
#  ('ricci', 1.463255402256019),
#  ('reflective', 1.463255402256019),
#  ('persistent', 1.463255402256019),
#  ('toto', 1.463255402256019),
#  ('dublin', 1.463255402256019),
#  ('comprehensive', 1.463255402256019),
#  ('splendid', 1.4624557220854546),
#  ('travolta', 1.455287232606842),
#  ('meek', 1.455287232606842),
#  ('cloak', 1.455287232606842),
#  ('tender', 1.4535465881290581),
#  ('exceptional', 1.4493524970870277),
#  ('highlighted', 1.4488147181012245),
#  ('drawback', 1.4488147181012245),
#  ('instrumental', 1.4488147181012245),
#  ('mordrid', 1.4488147181012245),
#  ('astute', 1.4488147181012245),
#  ('ably', 1.4488147181012245),
#  ('maintains', 1.4479879301252305),
#  ('shin', 1.4479879301252305),
#  ('gentle', 1.444705123276305),
#  ('ruby', 1.4442170088525952),
#  ('chan', 1.4441617434404395),
#  ('pathos', 1.4420857207483062),
#  ('ppv', 1.4389380946053125),
#  ('downside', 1.4389380946053125),
#  ('renoir', 1.4389380946053125),
#  ('marvellous', 1.4389380946053125),
#  ('shootings', 1.4389380946053125),
#  ('colourful', 1.4389380946053125),
#  ('soles', 1.4389380946053125),
#  ('cerebral', 1.4331256608039895),
#  ('restrained', 1.4331256608039895),
#  ('prophet', 1.431756735196648),
#  ('rizzo', 1.431756735196648),
#  ('dickens', 1.4311449272852423),
#  ('poignant', 1.4295443449137073),
#  ('everett', 1.4262996957335898),
#  ('sentinel', 1.4240346891027378),
#  ('favourites', 1.4220124437219699),
#  ('captivating', 1.4216337275651996),
#  ('fisher', 1.4188705315545034),
#  ('davies', 1.4188705315545034),
#  ('neglected', 1.418555223338112),
#  ('elegant', 1.4178997005352216),
#  ('rewarding', 1.415708246326184),
#  ('pixar', 1.4112956633253078),
#  ('chilling', 1.4111095302396146),
#  ('blackwood', 1.4060969884160703),
#  ('beads', 1.4060969884160703),
#  ('precursor', 1.4060969884160703),
#  ('timely', 1.4060969884160703),
#  ('strangeness', 1.4060969884160703),
#  ('stormy', 1.4060969884160703),
#  ('reaper', 1.4060969884160703),
#  ('powerhouse', 1.4060969884160703),
#  ('publish', 1.4060969884160703),
#  ('chord', 1.4060969884160703),
#  ('havana', 1.4060969884160703),
#  ('insecurities', 1.4060969884160703),
#  ('elton', 1.4060969884160703),
#  ('priya', 1.4060969884160703),
#  ('loan', 1.4060969884160703),
#  ('persuades', 1.4060969884160703),
#  ('melodramas', 1.4060969884160703),
#  ('gem', 1.4048563789799502),
#  ('gerard', 1.404476680203081),
#  ('fenton', 1.4022947024663317),
#  ('intertwined', 1.4022947024663317),
#  ('graceful', 1.4022947024663317),
#  ...]

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# Note: Above is the code Andrew uses in his solution video, 
#       so we've included it here to avoid confusion.
#       If you explore the documentation for the Counter class, 
#       you will see you could also find the 30 least common
#       words like this: pos_neg_ratios.most_common()[:-31:-1]
# Out:
# [('boll', -4.9640094527562),
#  ('uwe', -4.616769321831443),
#  ('thunderbirds', -4.113602378826515),
#  ('beowulf', -4.097118489104826),
#  ('dahmer', -3.9734316335567894),
#  ('wayans', -3.915350795520821),
#  ('ajay', -3.8536874284151827),
#  ('grendel', -3.8536874284151827),
#  ('awfulness', -3.6419625343261846),
#  ('seagal', -3.6386820502470227),
#  ('steaming', -3.615412302232064),
#  ('welch', -3.5881378843124043),
#  ('deathstalker', -3.531250509910353),
#  ('interminable', -3.4067375620377707),
#  ('sabretooth', -3.4067375620377707),
#  ('forwarding', -3.373026504695459),
#  ('devgan', -3.3381392456950185),
#  ('gamera', -3.3172117255890625),
#  ('varma', -3.264486336120253),
#  ('picker', -3.264486336120253),
#  ('razzie', -3.264486336120253),
#  ('dreck', -3.2602310105501147),
#  ('unwatchable', -3.2500514423366504),
#  ('stinker', -3.2003723533036412),
#  ('nada', -3.1849742731925192),
#  ('nostril', -3.1427144639026365),
#  ('kirkland', -3.1427144639026365),
#  ('giamatti', -3.1427144639026365),
#  ('appallingly', -3.0985896589936988),
#  ('aag', -3.0985896589936988)]

# %% [markdown]
# # End of Project 1.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
#
# # Transforming Text into Numbers<a id='lesson_3'></a>
# The cells here include code Andrew shows in the next video. We've included it so you can run the code along with the video without having to type in everything.

# %%
from IPython.display import Image

review = "This was a horrible, terrible movie."

Image(filename='sentiment_network.png')

# %%
review = "The movie was excellent"

Image(filename='sentiment_network_pos.png')

# %% [markdown]
# # Project 2: Creating the Input/Output Data<a id='project_2'></a>
#
# **TODO:** Create a [set](https://docs.python.org/3/tutorial/datastructures.html#sets) named `vocab` that contains every word in the vocabulary.

# %%
# TODO: Create set named "vocab" containing all of the words from all of the reviews
vocab = set(total_counts.elements())

# %% [markdown]
# Run the following cell to check your vocabulary size. If everything worked correctly, it should print **74074**

# %%
vocab_size = len(vocab)
print(vocab_size)
# Out:
# 74074

# %% [markdown]
# Take a look at the following image. It represents the layers of the neural network you'll be building throughout this notebook. `layer_0` is the input layer, `layer_1` is a hidden layer, and `layer_2` is the output layer.

# %%
from IPython.display import Image
Image(filename='sentiment_network_2.png')

# %% [markdown]
# **TODO:** Create a numpy array called `layer_0` and initialize it to all zeros. You will find the [zeros](https://docs.scipy.org/doc/numpy/reference/generated/numpy.zeros.html) function particularly helpful here. Be sure you create `layer_0` as a 2-dimensional matrix with 1 row and `vocab_size` columns.

# %%
# TODO: Create layer_0 matrix with dimensions 1 by vocab_size, initially filled with zeros
layer_0 = np.zeros((1,vocab_size))

# %% [markdown]
# Run the following cell. It should display `(1, 74074)`

# %%
layer_0.shape
# Out:
# (1, 74074)

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %% [markdown]
# `layer_0` contains one entry for every word in the vocabulary, as shown in the above image. We need to make sure we know the index of each word, so run the following cell to create a lookup table that stores the index of every word.

# %%
# Create a dictionary of words in the vocabulary mapped to index positions
# (to be used in layer_0)
word2index = {}
for i,word in enumerate(vocab):
    word2index[word] = i
    
# display the map of words to indices
word2index
# Out:
# {'': 0,
#  'mcpherson': 14440,
#  'bayreuth': 1,
#  'probes': 2,
#  'suicide': 66416,
#  'coarsened': 61697,
#  'enhancer': 3,
#  'cuoco': 4,
#  'flagrant': 5,
#  'eschatology': 6,
#  'atkins': 12373,
#  'monument': 11732,
#  'estelle': 7,
#  'doos': 8,
#  'rider': 9,
#  'sigh': 6202,
#  'amphibious': 11,
#  'nibelungenlied': 12375,
#  'prohibitions': 12,
#  'clinching': 14,
#  'klown': 24675,
#  'dignify': 15,
#  'helfgotts': 16,
#  'stewert': 6430,
#  'leben': 18,
#  'rehabilitated': 27547,
#  'arbore': 19,
#  'signify': 20,
#  'stringy': 21,
#  'decal': 22,
#  'manuel': 26,
#  'mulrooney': 24,
#  'humphrey': 25,
#  'zillionaire': 37044,
#  'ultramagnetic': 27,
#  'unneccessary': 61701,
#  'ingor': 31,
#  'grooviest': 29,
#  'clunky': 30,
#  'baring': 32,
#  'dorlan': 36,
#  'bearcats': 34,
#  'emboldened': 35,
#  'burqas': 37,
#  'resmblance': 38,
#  'setting': 39,
#  'anorectic': 41,
#  'theorize': 42,
#  'excels': 61703,
#  'macho': 71734,
#  'damner': 35733,
#  'ineffably': 56178,
#  'matkondar': 46,
#  'outshone': 24682,
#  'olajima': 45,
#  'distilled': 49464,
#  'singhs': 47,
#  'extravant': 48,
#  'marvelling': 50,
#  'whales': 51,
#  'fett': 53,
#  'hime': 54,
#  'kruegers': 55,
#  'capitalise': 58,
#  'upham': 57,
#  'darwinism': 59,
#  'blanks': 37053,
#  'hierarchy': 60,
#  'pised': 46732,
#  'forton': 62,
#  'revisiting': 63,
#  'yoko': 64,
#  'finnish': 65,
#  'sequals': 66,
#  'ros': 68,
#  'hallmark': 24688,
#  'chandrmukhi': 70,
#  'methaphor': 61711,
#  'lyric': 71,
#  'insted': 73796,
#  'roofthooft': 10,
#  'antonionian': 72,
#  'jefferies': 73,
#  'beermat': 74,
#  'supersoldiers': 24691,
#  'skimp': 75,
#  'finales': 76,
#  'paws': 78,
#  'macek': 80,
#  'eroding': 81,
#  'weaving': 82,
#  'mo': 69258,
#  'leesa': 84,
#  'anxieties': 85,
#  'scam': 16590,
#  'pascal': 86,
#  'scarefests': 87,
#  'daimajin': 88,
#  'catologed': 89,
#  'kristin': 90,
#  'toussaint': 91,
#  'appease': 13,
#  'perils': 24697,
#  'athleticism': 92,
#  'riggers': 94,
#  'abhimaan': 95,
#  'zwrite': 53791,
#  'primus': 99,
#  'wracking': 97,
#  'artyfartyrati': 48772,
#  'rebuttle': 102,
#  'hicock': 101,
#  'baurel': 65411,
#  'farenheight': 37059,
#  'supplant': 103,
#  'trailblazers': 104,
#  'lindstrom': 106,
#  'ramo': 109,
#  'embroidered': 111,
#  'dailey': 110,
#  'dateing': 17,
#  'achterbusch': 112,
#  'purely': 113,
#  'geologists': 116,
#  'florida': 115,
#  'spraypainted': 123,
#  'snafu': 118,
#  'karloff': 119,
#  'interspecial': 121,
#  'memorized': 37061,
#  'wallpaper': 124,
#  'kaleidiscopic': 125,
#  'fletcher': 49472,
#  'schiller': 126,
#  'disapproves': 127,
#  'harrowing': 61719,
#  'sforza': 129,
#  'dammes': 61721,
#  'disagree': 49474,
#  'dealership': 131,
#  'skill': 37063,
#  'crucible': 132,
#  'mendacious': 24703,
#  'salutory': 133,
#  'propagandistic': 61723,
#  'ignatova': 135,
#  'veda': 137,
#  'shahrukhed': 65668,
#  'believes': 138,
#  'hitter': 139,
#  'demi': 140,
#  'gravestones': 61229,
#  'bombarded': 144,
#  'slogging': 143,
#  'bitter': 24705,
#  'loathe': 12400,
#  'apophis': 37067,
#  'stockinged': 145,
#  'perplexing': 146,
#  'crepe': 147,
#  'leolo': 68038,
#  'yawned': 148,
#  'unwittingly': 149,
#  'apres': 150,
#  'magon': 152,
#  'fonze': 153,
#  'hercules': 154,
#  'withdrawal': 155,
#  'digesting': 157,
#  'enantiodromia': 158,
#  'mosaic': 159,
#  'straithrain': 160,
#  'limitations': 161,
#  'archrivals': 162,
#  'occupant': 164,
#  'esau': 165,
#  'columbo': 167,
#  'fella': 168,
#  'questioner': 169,
#  'taqueria': 170,
#  'mandates': 171,
#  'clientele': 24710,
#  'lecture': 173,
#  'overplays': 49479,
#  'mainstream': 175,
#  'quicksand': 176,
#  'dissects': 177,
#  'inca': 12404,
#  'pranksters': 181,
#  'almonds': 182,
#  'affixed': 183,
#  'cohl': 69197,
#  'margotta': 186,
#  'mccarey': 23,
#  'yashiro': 187,
#  'negotiator': 189,
#  'haifa': 12408,
#  'dub': 190,
#  'abetted': 191,
#  'requiem': 193,
#  'misdemeanors': 194,
#  'reaction': 195,
#  'unsupported': 197,
#  'hotbed': 56789,
#  'blanked': 24714,
#  'dinning': 199,
#  'move': 200,
#  'sextet': 201,
#  'fanatics': 202,
#  'capitalised': 203,
#  'workhouse': 204,
#  'hygiene': 205,
#  'depressive': 208,
#  'savior': 209,
#  'cremation': 210,
#  'voted': 211,
#  'invoking': 213,
#  'maddie': 214,
#  'pvc': 215,
#  'process': 216,
#  'glenaan': 217,
#  'jidai': 218,
#  'revenues': 219,
#  'deanesque': 66092,
#  'neutralise': 220,
#  'schematically': 221,
#  'trruck': 222,
#  'prostitute': 223,
#  'jace': 224,
#  'pollutes': 33,
#  'loyd': 229,
#  'sobriety': 227,
#  'patched': 228,
#  'gear': 37080,
#  'kelada': 231,
#  'fuller': 232,
#  'burns': 233,
#  'critiquing': 234,
#  'favours': 235,
#  'hughes': 237,
#  'ipso': 238,
#  'watcher': 239,
#  'sharawat': 61734,
#  'disputable': 240,
#  'massiah': 241,
#  'supposes': 37087,
#  'loathing': 242,
#  'doreen': 243,
#  'power': 12418,
#  'hatian': 247,
#  'libidinous': 251,
#  'delane': 248,
#  'deployment': 250,
#  'disorganized': 253,
#  'blowing': 17768,
#  'minor': 37089,
#  'altamont': 255,
#  'sibilant': 257,
#  'whooped': 260,
#  'completing': 57644,
#  'romany': 261,
#  'jeans': 262,
#  'li': 263,
#  'gorily': 43329,
#  'cossimo': 267,
#  'shrunk': 61743,
#  'wacks': 268,
#  'floyd': 269,
#  'jarmila': 270,
#  'dorado': 72069,
#  'turncoat': 61744,
#  'medication': 271,
#  'death': 272,
#  'methadrine': 275,
#  'nullifies': 278,
#  'enigmatically': 277,
#  'resiliency': 279,
#  'rekindling': 280,
#  'abstracted': 281,
#  'boingo': 282,
#  'bargain': 61746,
#  'misdirected': 56049,
#  'cinevista': 283,
#  'elizbethan': 284,
#  'mofo': 67324,
#  'zillion': 286,
#  'frisco': 287,
#  'brahms': 288,
#  'fetishises': 70382,
#  'connory': 289,
#  'transpired': 292,
#  'brazilian': 291,
#  'dansu': 70454,
#  'hobos': 293,
#  'marches': 69849,
#  'natsuyagi': 12426,
#  'shocker': 59066,
#  'distorts': 16839,
#  'amoral': 68205,
#  'tractor': 294,
#  'enchants': 295,
#  'horrifies': 51861,
#  'similes': 298,
#  'langa': 299,
#  'ferencz': 300,
#  'unrelated': 301,
#  'socioty': 72617,
#  'surfed': 303,
#  'viscontian': 55221,
#  'likelihood': 304,
#  'trialat': 305,
#  'zasu': 306,
#  'ebts': 308,
#  'wheelies': 310,
#  'nisep': 311,
#  'musalman': 313,
#  'addison': 50540,
#  'suchet': 314,
#  'pados': 315,
#  'nishaabd': 317,
#  'coffin': 318,
#  'constanly': 12427,
#  'embattled': 322,
#  'shaggy': 320,
#  'mikel': 321,
#  'joxs': 18734,
#  'cowards': 323,
#  'riverside': 324,
#  'somnolence': 49503,
#  'carpeting': 325,
#  'emile': 326,
#  'gildersleeves': 61757,
#  'industrialisation': 327,
#  'girlfrined': 12430,
#  'peeled': 328,
#  'schwarzenbach': 329,
#  'keywords': 330,
#  'butlins': 25855,
#  'sabc': 331,
#  'fatefirst': 49,
#  'lasting': 332,
#  'coleen': 333,
#  'agency': 334,
#  'remotest': 61760,
#  'cavalcade': 17153,
#  'backstories': 338,
#  'armored': 336,
#  'asco': 52569,
#  'reimbursement': 339,
#  'sandcastles': 340,
#  'blemish': 341,
#  'purchased': 343,
#  'stubble': 49506,
#  'pushovers': 345,
#  'ebeneezer': 346,
#  'cleansed': 1711,
#  'neglecting': 347,
#  'merits': 348,
#  'occupations': 350,
#  'dutton': 351,
#  'grader': 353,
#  'disregards': 354,
#  'smitten': 12441,
#  'nepalease': 355,
#  'midseason': 356,
#  'leviathan': 43334,
#  'tbh': 357,
#  'maccarthy': 52,
#  'australians': 358,
#  'chitre': 24735,
#  'departs': 359,
#  'masaru': 51486,
#  'inanimate': 360,
#  'erect': 361,
#  'gavriil': 363,
#  'skinniness': 364,
#  'mobiles': 366,
#  'sudachan': 367,
#  'thinly': 368,
#  'psychiatrists': 369,
#  'beating': 370,
#  'abhor': 372,
#  'loaned': 65172,
#  'fyodor': 373,
#  'direct': 61952,
#  'defectives': 374,
#  'shabbiness': 375,
#  'cohn': 377,
#  'tinkers': 378,
#  'learnfrom': 379,
#  'jawed': 380,
#  'shoebox': 381,
#  'egypt': 24742,
#  'fascist': 49513,
#  'samara': 382,
#  'laemmles': 383,
#  'broadcasting': 385,
#  'gelo': 386,
#  'subdivisions': 388,
#  'praising': 61769,
#  'versa': 389,
#  'cullen': 390,
#  'implant': 391,
#  'beenville': 393,
#  'titains': 394,
#  'barb': 396,
#  'incidences': 49516,
#  'tusks': 56755,
#  'yippeeee': 398,
#  'you': 399,
#  'shed': 400,
#  'pleasence': 401,
#  'pulses': 402,
#  'floodlights': 403,
#  'brylcreem': 404,
#  'seizures': 406,
#  'goodluck': 407,
#  'humm': 408,
#  'identi': 409,
#  'montanas': 73135,
#  'duane': 411,
#  'carriage': 412,
#  'junkie': 61,
#  'shorelines': 413,
#  'kenyon': 414,
#  'malone': 415,
#  'scholl': 418,
#  'representations': 417,
#  'nations': 52914,
#  'antecedents': 419,
#  'confederation': 420,
#  'cipriani': 421,
#  'burstingly': 37111,
#  'pumkinhead': 422,
#  'pigeon': 423,
#  'mora': 425,
#  'hennenlotter': 27403,
#  'righting': 49521,
#  'abyss': 426,
#  'sector': 49909,
#  'paraphernalia': 427,
#  'customers': 428,
#  'plural': 429,
#  'bullhit': 17080,
#  'downgraded': 64550,
#  'borradaile': 51551,
#  'broncho': 67,
#  'standpoints': 430,
#  'sidebar': 431,
#  'esthetically': 432,
#  'bachman': 24753,
#  'creepfest': 434,
#  'solomon': 435,
#  'arduous': 436,
#  'conflated': 439,
#  'enterprise': 438,
#  'alternate': 440,
#  'pretenders': 442,
#  'nair': 443,
#  'awesome': 444,
#  'realistically': 445,
#  'korean': 446,
#  'lasso': 447,
#  'unreservedly': 72421,
#  'rogerson': 449,
#  'neno': 12459,
#  'handsome': 450,
#  'minging': 60530,
#  'heists': 61776,
#  'abominator': 451,
#  'reifenstal': 452,
#  'mccheese': 454,
#  'hiccuping': 18588,
#  'conte': 458,
#  'quarreling': 457,
#  'coast': 69,
#  'sbardellati': 460,
#  'crasher': 461,
#  'chin': 463,
#  'meats': 28422,
#  'kendal': 464,
#  'jesues': 466,
#  'recited': 73940,
#  'limerick': 468,
#  'priestly': 469,
#  'sugarcoated': 470,
#  'org': 471,
#  'venal': 472,
#  'soiler': 473,
#  'grossed': 475,
#  'assuage': 476,
#  'mahalovic': 49529,
#  'expand': 477,
#  'timesin': 478,
#  'subspace': 479,
#  'lange': 480,
#  'semisubmerged': 482,
#  'broadest': 483,
#  'idioterne': 484,
#  'lighting': 37120,
#  'windscreen': 485,
#  'bratt': 487,
#  'barlow': 488,
#  'offs': 489,
#  'okerlund': 490,
#  'onslow': 491,
#  'laud': 492,
#  'gilmore': 493,
#  'hahahahaha': 494,
#  'burnsallen': 496,
#  'boringest': 497,
#  'sachar': 499,
#  'priestley': 500,
#  'dissabordinate': 501,
#  'peacefulending': 502,
#  'knowingly': 503,
#  'valeriana': 506,
#  'expressionless': 505,
#  'wg': 31697,
#  'fred': 507,
#  'tracksuits': 509,
#  'vollins': 71528,
#  'birthmark': 63029,
#  'namers': 512,
#  'derail': 513,
#  'munna': 515,
#  'priority': 517,
#  'kearn': 12467,
#  'heah': 519,
#  'emeryville': 521,
#  'wig': 61783,
#  'erases': 522,
#  'unfilmed': 523,
#  'bgs': 524,
#  'civics': 525,
#  'sublimely': 526,
#  'uncoventional': 77,
#  'hoggish': 531,
#  'yugi': 529,
#  'stuffiness': 530,
#  'exhibit': 532,
#  'yields': 533,
#  'constrictor': 70656,
#  'heartstopping': 534,
#  'neutron': 535,
#  'anxious': 536,
#  'hopfel': 537,
#  'headlight': 542,
#  'mitsugoro': 539,
#  'clunkier': 540,
#  'nautilus': 547,
#  'thriller': 546,
#  'surnamed': 548,
#  'popcorncoke': 549,
#  'doped': 550,
#  'wayyyyy': 551,
#  'cherri': 552,
#  'gliss': 554,
#  'colomb': 555,
#  'freak': 556,
#  'invigorating': 79,
#  'crookedly': 558,
#  'accuracies': 559,
#  'fantasized': 560,
#  'impactive': 561,
#  'merciful': 562,
#  'skoda': 563,
#  'lungren': 564,
#  'gameboy': 37131,
#  'licker': 61791,
#  'ignite': 566,
#  'seduces': 567,
#  'lateesha': 572,
#  'firmament': 570,
#  'udit': 571,
#  'tubbs': 573,
#  'inmates': 574,
#  'timbo': 575,
#  'proctologist': 576,
#  'dooooosie': 577,
#  'artisans': 578,
#  'boggins': 581,
#  'renn': 580,
#  'averages': 24781,
#  'pensaba': 582,
#  'commemorating': 583,
#  'charcoal': 72517,
#  'wether': 12473,
#  'convolute': 586,
#  'lazers': 585,
#  'vacillate': 587,
#  'naysayer': 588,
#  'kep': 589,
#  'pliskin': 592,
#  'hastens': 593,
#  'cumentery': 24785,
#  'candide': 594,
#  'wilkins': 596,
#  'bruhls': 597,
#  'mlaatr': 598,
#  'cundieff': 599,
#  'crashers': 600,
#  'notte': 601,
#  'pheobe': 602,
#  'linguistic': 604,
#  'quinton': 37142,
#  'khleo': 613,
#  'marinated': 606,
#  'overworking': 612,
#  'winglies': 608,
#  'ivanek': 609,
#  'shoppers': 611,
#  'steptoe': 614,
#  'lavender': 615,
#  'weel': 616,
#  'dance': 49552,
#  'columned': 618,
#  'andersons': 619,
#  'triumphant': 620,
#  'griminess': 622,
#  'horsecoach': 623,
#  'lanky': 12478,
#  'longingly': 624,
#  'blackish': 625,
#  'beta': 628,
#  'chested': 61799,
#  'waged': 630,
#  'nearne': 62578,
#  'cgis': 631,
#  'mystified': 632,
#  'cusacks': 633,
#  'hiasashi': 634,
#  'passively': 635,
#  'carousel': 636,
#  'talkies': 638,
#  'villainizing': 28147,
#  'attainable': 639,
#  'elongate': 640,
#  'hermeneutic': 641,
#  'abilityof': 642,
#  'deservingly': 643,
#  'coffey': 644,
#  'pawn': 645,
#  'sharpshooters': 647,
#  'diapers': 648,
#  'regurgitation': 649,
#  'regime': 651,
#  'intimist': 61804,
#  'muncie': 652,
#  'gillan': 653,
#  'vidpic': 654,
#  'counterpoints': 655,
#  'incognizant': 49561,
#  'modulate': 656,
#  'regained': 12488,
#  'hallie': 93,
#  'weathered': 657,
#  'loews': 658,
#  'repoire': 12489,
#  'hasnt': 660,
#  'premised': 51718,
#  'element': 661,
#  'endless': 662,
#  'stridence': 51104,
#  'downhill': 65183,
#  'gere': 663,
#  'norseman': 664,
#  'miserable': 665,
#  'tasteful': 666,
#  'languor': 672,
#  'aroona': 668,
#  'patrice': 669,
#  'brainy': 670,
#  'curtain': 96,
#  'demon': 674,
#  'sexo': 30538,
#  'eschenbach': 675,
#  'disassociate': 676,
#  'belatedly': 72483,
#  'buschemi': 677,
#  'slide': 12490,
#  'splendors': 678,
#  'ethier': 679,
#  'curse': 680,
#  'crumble': 681,
#  'stewart': 682,
#  'mastrantonio': 683,
#  'parkins': 684,
#  'misbehaves': 685,
#  'ettore': 100,
#  'entrances': 688,
#  'occasional': 689,
#  'loafs': 50801,
#  'gritting': 691,
#  'revolutionised': 696,
#  'goldies': 693,
#  'loewe': 695,
#  'jagger': 697,
#  'twangy': 700,
#  'strin': 12495,
#  'cowers': 701,
#  'abdu': 702,
#  'blade': 37160,
#  'chans': 56946,
#  'online': 703,
#  'rolls': 50265,
#  'halperins': 706,
#  'brookmyre': 105,
#  'severeid': 708,
#  'eclectic': 709,
#  'peripheral': 12498,
#  'months': 711,
#  'plant': 65652,
#  'trautman': 25117,
#  'ca': 713,
#  'descendants': 714,
#  'exuded': 715,
#  'yesteryears': 52288,
#  'craftsman': 718,
#  'partial': 61814,
#  'lessened': 719,
#  'jarman': 58380,
#  'ova': 720,
#  'meagre': 721,
#  'mashed': 49571,
#  'lighthouse': 722,
#  'juscar': 107,
#  'lopes': 724,
#  'lapsing': 725,
#  'dandylion': 729,
#  'practice': 108,
#  'naysayers': 730,
#  'verma': 67814,
#  'benchmark': 731,
#  'breeds': 732,
#  'skeptiscism': 733,
#  'ushered': 734,
#  'cracker': 735,
#  'rivaled': 737,
#  'lowood': 69065,
#  'thief': 738,
#  'mainframe': 739,
#  'varotto': 742,
#  'tellings': 743,
#  'ohhh': 744,
#  'easterns': 746,
#  'unfrozen': 747,
#  'pointer': 748,
#  'furnace': 749,
#  'spirts': 750,
#  'scorpiolina': 751,
#  'mistakes': 753,
#  'bundle': 69423,
#  'flamboyance': 755,
#  'dv': 114,
#  'joel': 12508,
#  'meier': 758,
#  'aada': 759,
#  'hideous': 763,
#  'shibasaki': 764,
#  'ep': 762,
#  'rocks': 765,
#  'soared': 766,
#  'syberia': 767,
#  'tonal': 768,
#  'no': 769,
#  'ultramodern': 771,
#  'opting': 772,
#  'depressing': 773,
#  'tuner': 774,
#  'pie': 778,
#  'cliffhanging': 779,
#  'betrayed': 780,
#  'expository': 781,
#  'donavon': 783,
#  'kristel': 120,
#  'itits': 784,
#  'feebles': 62731,
#  'doh': 785,
#  'jenner': 49580,
#  'delineation': 787,
#  'fugue': 788,
#  'gaps': 16771,
#  'candace': 789,
#  'zoltan': 790,
#  'plough': 791,
#  'adventures': 24806,
#  'capers': 792,
#  'visayan': 793,
#  'hander': 794,
#  'yemen': 795,
#  'abdicating': 797,
#  'mingled': 798,
#  'heed': 799,
#  'mechapiloting': 800,
#  'abducted': 801,
#  'unraveling': 61825,
#  'suarez': 805,
#  'pilippinos': 806,
#  'scenarios': 807,
#  'pirotess': 808,
#  'rien': 61826,
#  'lizard': 809,
#  'adultery': 810,
#  'chameleon': 811,
#  'buffoonery': 58922,
#  'relapsing': 813,
#  'bradys': 814,
#  'reek': 817,
#  'keppel': 816,
#  'goofing': 818,
#  'nadie': 822,
#  'tarri': 820,
#  'chair': 821,
#  'aflame': 824,
#  'wizardly': 825,
#  'muslims': 826,
#  'assessing': 828,
#  'laughometer': 829,
#  'jacket': 831,
#  'gazed': 832,
#  'crossover': 24812,
#  'estranged': 53810,
#  'hoffmann': 833,
#  'densely': 834,
#  'eleonora': 24813,
#  'playgroud': 835,
#  'drea': 836,
#  'mallaig': 73437,
#  'cell': 837,
#  'syndrome': 49584,
#  'pronouncement': 838,
#  'ganghis': 839,
#  'whoopi': 840,
#  'istvan': 53279,
#  'allude': 49586,
#  'crevices': 843,
#  'cervi': 844,
#  'underdogs': 846,
#  'enviable': 847,
#  'swag': 848,
#  'burgle': 849,
#  'generis': 850,
#  'rushton': 855,
#  'introversion': 852,
#  'anticipates': 853,
#  'mysoju': 857,
#  'hoek': 858,
#  'wiseass': 49589,
#  'lib': 859,
#  'darma': 861,
#  'herods': 862,
#  'brushes': 863,
#  'stabilize': 37181,
#  'hooray': 864,
#  'reviles': 865,
#  'happening': 866,
#  'kinsella': 868,
#  'androvsky': 869,
#  'gryphons': 870,
#  'royersford': 871,
#  'beanies': 872,
#  'distinguishes': 873,
#  'psh': 874,
#  'supercomputer': 73626,
#  'kenitalia': 875,
#  'trampy': 876,
#  'fingerprinting': 55197,
#  'workweeks': 879,
#  'boning': 878,
#  'hilarius': 134,
#  'fiernan': 880,
#  'wading': 881,
#  'incorruptible': 24821,
#  'unduly': 882,
#  'institutions': 883,
#  'appliance': 5818,
#  'smooching': 886,
#  'repackaging': 57643,
#  'bressart': 887,
#  'ejection': 888,
#  'conteras': 889,
#  'doritos': 890,
#  'sinuous': 891,
#  'gehrig': 68528,
#  'dukakis': 892,
#  'ripostes': 893,
#  'nielson': 894,
#  'licentious': 895,
#  'richar': 896,
#  'pollen': 897,
#  'calling': 37188,
#  'mattia': 898,
#  'mcconnohie': 49595,
#  'courius': 899,
#  'temple': 900,
#  'literally': 901,
#  'steadfast': 902,
#  'josha': 903,
#  'eads': 904,
#  'disproportionally': 905,
#  'deprive': 906,
#  'spirogolou': 37190,
#  'blamed': 907,
#  'flores': 910,
#  'amazement': 909,
#  'terorism': 911,
#  'mollusks': 912,
#  'strictures': 913,
#  'julissa': 914,
#  'filler': 915,
#  'neise': 142,
#  'marionette': 917,
#  'whalin': 918,
#  'whisked': 919,
#  'squid': 49599,
#  'flea': 923,
#  'europe': 921,
#  'rejecting': 922,
#  'mingozzi': 925,
#  'tiki': 64939,
#  'bests': 927,
#  'standup': 928,
#  'overhauled': 929,
#  'hermit': 930,
#  'smooths': 931,
#  'uomini': 932,
#  'friendliness': 933,
#  'highlighting': 934,
#  'entertainent': 935,
#  'baffel': 936,
#  'villedo': 937,
#  'hindrance': 938,
#  'cameos': 939,
#  'smugglers': 940,
#  'telepath': 941,
#  'overreach': 942,
#  'lembeck': 49383,
#  'syrupy': 943,
#  'piscapo': 944,
#  'moron': 946,
#  'klasky': 67659,
#  'antagonized': 947,
#  'oppikoppi': 948,
#  'rewarded': 949,
#  'hjalmar': 950,
#  'petites': 954,
#  'revealled': 952,
#  'caco': 957,
#  'desent': 956,
#  'import': 54851,
#  'chokes': 958,
#  'wacthing': 964,
#  'tart': 960,
#  'flique': 961,
#  'sloshed': 962,
#  'princeton': 963,
#  'lated': 965,
#  'samundar': 24844,
#  'zumhofe': 966,
#  'mooommmm': 967,
#  'discer': 18406,
#  'squashed': 968,
#  'sipus': 970,
#  'roughneck': 68839,
#  'tofu': 972,
#  'fireballs': 63254,
#  'gunfighters': 973,
#  'swd': 974,
#  'bald': 61855,
#  'carerra': 976,
#  'ferries': 68772,
#  'analytical': 977,
#  'danson': 978,
#  'curitz': 979,
#  'mutes': 980,
#  'atc': 985,
#  'slug': 984,
#  'semblance': 983,
#  'kalser': 63867,
#  'yelena': 12550,
#  'cassettes': 988,
#  'roughie': 989,
#  'manerisms': 990,
#  'unredeeming': 991,
#  'sandoval': 992,
#  'arson': 12552,
#  'exposition': 993,
#  'externalization': 994,
#  'luege': 995,
#  'irwins': 996,
#  'pushes': 997,
#  'placed': 998,
#  'freeform': 31254,
#  'claustraphobia': 1001,
#  'usurer': 1002,
#  'penetrator': 1003,
#  'silent': 1004,
#  'seond': 61860,
#  'jerkingly': 1005,
#  ...}

# %% [markdown]
# **TODO:**  Complete the implementation of `update_input_layer`. It should count
#           how many times each word is used in the given review, and then store
#           those counts at the appropriate indices inside `layer_0`.

# %%
def update_input_layer(review):
    """ Modify the global layer_0 to represent the vector form of review.
    The element at a given index of layer_0 should represent
    how many times the given word occurs in the review.
    Args:
        review(string) - the string of the review
    Returns:
        None
    """
    global layer_0
    # clear out previous state by resetting the layer to be all 0s
    layer_0 *= 0
    
    # TODO: count how many times each word is used in the given review and store the results in layer_0 
    for word in review.split(' '):
        layer_0[0][word2index[word]] += 1

# %% [markdown]
# Run the following cell to test updating the input layer with the first review. The indices assigned may not be the same as in the solution, but hopefully you'll see some non-zero values in `layer_0`.

# %%
update_input_layer(reviews[0])
layer_0
# Out:
# array([[18.,  0.,  0., ...,  0.,  0.,  0.]])

# %% [markdown]
# **TODO:** Complete the implementation of `get_target_for_labels`. It should return `0` or `1`,
#           depending on whether the given label is `NEGATIVE` or `POSITIVE`, respectively.

# %%
def get_target_for_label(label):
    """Convert a label to `0` or `1`.
    Args:
        label(string) - Either "POSITIVE" or "NEGATIVE".
    Returns:
        `0` or `1`.
    """
    # TODO: Your code here
    if label == "POSITIVE":
        return 1
    else:
        return 0

# %% [markdown]
# Run the following two cells. They should print out`'POSITIVE'` and `1`, respectively.

# %%
labels[0]
# Out:
# 'POSITIVE'

# %%
get_target_for_label(labels[0])
# Out:
# 1

# %% [markdown]
# Run the following two cells. They should print out `'NEGATIVE'` and `0`, respectively.

# %%
labels[1]
# Out:
# 'NEGATIVE'

# %%
get_target_for_label(labels[1])
# Out:
# 0

# %% [markdown]
# # End of Project 2.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Project 3: Building a Neural Network<a id='project_3'></a>

# %% [markdown]
# **TODO:** We've included the framework of a class called `SentimentNetork`. Implement all of the items marked `TODO` in the code. These include doing the following:
# - Create a basic neural network much like the networks you've seen in earlier lessons and in Project 1, with an input layer, a hidden layer, and an output layer.
# - Do **not** add a non-linearity in the hidden layer. That is, do not use an activation function when calculating the hidden layer outputs.
# - Re-use the code from earlier in this notebook to create the training data (see `TODO`s in the code)
# - Implement the `pre_process_data` function to create the vocabulary for our training data generating functions
# - Ensure `train` trains over the entire corpus

# %% [markdown]
# ### Where to Get Help if You Need it
# - Re-watch earlier Udacity lectures
# - Chapters 3-5 - [Grokking Deep Learning](https://www.manning.com/books/grokking-deep-learning) - (Check inside your classroom for a discount code)

# %%
import time
import sys
import numpy as np

# Encapsulate our neural network in a class
class SentimentNetwork:
    def __init__(self, reviews, labels, hidden_nodes = 10, learning_rate = 0.1):
        """Create a SentimenNetwork with the given settings
        Args:
            reviews(list) - List of reviews used for training
            labels(list) - List of POSITIVE/NEGATIVE labels associated with the given reviews
            hidden_nodes(int) - Number of nodes to create in the hidden layer
            learning_rate(float) - Learning rate to use while training
        
        """
        # Assign a seed to our random number generator to ensure we get
        # reproducable results during development 
        np.random.seed(1)

        # process the reviews and their associated labels so that everything
        # is ready for training
        self.pre_process_data(reviews, labels)
        
        # Build the network to have the number of hidden nodes and the learning rate that
        # were passed into this initializer. Make the same number of input nodes as
        # there are vocabulary words and create a single output node.
        self.init_network(len(self.review_vocab),hidden_nodes, 1, learning_rate)

    def pre_process_data(self, reviews, labels):
        
        review_vocab = set()
        # TODO: populate review_vocab with all of the words in the given reviews
        #       Remember to split reviews into individual words 
        #       using "split(' ')" instead of "split()".
        
        # Convert the vocabulary set to a list so we can access words via indices
        self.review_vocab = list(review_vocab)
        
        label_vocab = set()
        # TODO: populate label_vocab with all of the words in the given labels.
        #       There is no need to split the labels because each one is a single word.
        
        # Convert the label vocabulary set to a list so we can access labels via indices
        self.label_vocab = list(label_vocab)
        
        # Store the sizes of the review and label vocabularies.
        self.review_vocab_size = len(self.review_vocab)
        self.label_vocab_size = len(self.label_vocab)
        
        # Create a dictionary of words in the vocabulary mapped to index positions
        self.word2index = {}
        # TODO: populate self.word2index with indices for all the words in self.review_vocab
        #       like you saw earlier in the notebook
        
        # Create a dictionary of labels mapped to index positions
        self.label2index = {}
        # TODO: do the same thing you did for self.word2index and self.review_vocab, 
        #       but for self.label2index and self.label_vocab instead
         
        
    def init_network(self, input_nodes, hidden_nodes, output_nodes, learning_rate):
        # Store the number of nodes in input, hidden, and output layers.
        self.input_nodes = input_nodes
        self.hidden_nodes = hidden_nodes
        self.output_nodes = output_nodes

        # Store the learning rate
        self.learning_rate = learning_rate

        # Initialize weights
        
        # TODO: initialize self.weights_0_1 as a matrix of zeros. These are the weights between
        #       the input layer and the hidden layer.
        self.weights_0_1 = None
        
        # TODO: initialize self.weights_1_2 as a matrix of random values. 
        #       These are the weights between the hidden layer and the output layer.
        self.weights_1_2 = None
        
        # TODO: Create the input layer, a two-dimensional matrix with shape 
        #       1 x input_nodes, with all values initialized to zero
        self.layer_0 = None
    
        
    def update_input_layer(self,review):
        # TODO: You can copy most of the code you wrote for update_input_layer 
        #       earlier in this notebook. 
        #
        #       However, MAKE SURE YOU CHANGE ALL VARIABLES TO REFERENCE
        #       THE VERSIONS STORED IN THIS OBJECT, NOT THE GLOBAL OBJECTS.
        #       For example, replace "layer_0 *= 0" with "self.layer_0 *= 0"
        pass
                
    def get_target_for_label(self,label):
        # TODO: Copy the code you wrote for get_target_for_label 
        #       earlier in this notebook. 
        pass
        
    def sigmoid(self,x):
        # TODO: Return the result of calculating the sigmoid activation function
        #       shown in the lectures
        pass
    
    def sigmoid_output_2_derivative(self,output):
        # TODO: Return the derivative of the sigmoid activation function, 
        #       where "output" is the original output from the sigmoid function 
        pass

    def train(self, training_reviews, training_labels):
        
        # make sure we have a matching number of reviews and labels
        assert(len(training_reviews) == len(training_labels))
        
        # Keep track of correct predictions to display accuracy during training 
        correct_so_far = 0
        
        # Remember when we started for printing time statistics
        start = time.time()

        # loop through all the given reviews and run a forward and backward pass,
        # updating weights for every item
        for i in range(len(training_reviews)):
            
            # TODO: Get the next review and its correct label
            
            # TODO: Implement the forward pass through the network. 
            #       That means use the given review to update the input layer, 
            #       then calculate values for the hidden layer,
            #       and finally calculate the output layer.
            # 
            #       Do not use an activation function for the hidden layer,
            #       but use the sigmoid activation function for the output layer.
            
            # TODO: Implement the back propagation pass here. 
            #       That means calculate the error for the forward pass's prediction
            #       and update the weights in the network according to their
            #       contributions toward the error, as calculated via the
            #       gradient descent and back propagation algorithms you 
            #       learned in class.
            
            # TODO: Keep track of correct predictions. To determine if the prediction was
            #       correct, check that the absolute value of the output error 
            #       is less than 0.5. If so, add one to the correct_so_far count.
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the training process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(training_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct_so_far) + " #Trained:" + str(i+1) \
                             + " Training Accuracy:" + str(correct_so_far * 100 / float(i+1))[:4] + "%")
            if(i % 2500 == 0):
                print("")
    
    def test(self, testing_reviews, testing_labels):
        """
        Attempts to predict the labels for the given testing_reviews,
        and uses the test_labels to calculate the accuracy of those predictions.
        """
        
        # keep track of how many correct predictions we make
        correct = 0

        # we'll time how many predictions per second we make
        start = time.time()

        # Loop through each of the given reviews and call run to predict
        # its label. 
        for i in range(len(testing_reviews)):
            pred = self.run(testing_reviews[i])
            if(pred == testing_labels[i]):
                correct += 1
            
            # For debug purposes, print out our prediction accuracy and speed 
            # throughout the prediction process. 

            elapsed_time = float(time.time() - start)
            reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
            
            sys.stdout.write("\rProgress:" + str(100 * i/float(len(testing_reviews)))[:4] \
                             + "% Speed(reviews/sec):" + str(reviews_per_second)[0:5] \
                             + " #Correct:" + str(correct) + " #Tested:" + str(i+1) \
                             + " Testing Accuracy:" + str(correct * 100 / float(i+1))[:4] + "%")
    
    def run(self, review):
        """
        Returns a POSITIVE or NEGATIVE prediction for the given review.
        """
        # TODO: Run a forward pass through the network, like you did in the
        #       "train" function. That means use the given review to 
        #       update the input layer, then calculate values for the hidden layer,
        #       and finally calculate the output layer.
        #
        #       Note: The review passed into this function for prediction 
        #             might come from anywhere, so you should convert it 
        #             to lower case prior to using it.
        
        # TODO: The output layer should now contain a prediction. 
        #       Return `POSITIVE` for predictions greater-than-or-equal-to `0.5`, 
        #       and `NEGATIVE` otherwise.
        pass

# %% [markdown]
# Run the following cell to create a `SentimentNetwork` that will train on all but the last 1000 reviews (we're saving those for testing). Here we use a learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)

# %% [markdown]
# Run the following cell to test the network's performance against the last 1000 reviews (the ones we held out from our training set).
#
# **We have not trained the model yet, so the results should be about 50% as it will just be guessing and there are only two possible values to choose from.**

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to actually train the network. During training, it will display the model's accuracy repeatedly as it trains so you can see how well it's doing.

# %%
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That most likely didn't train very well. Part of the reason may be because the learning rate is too high. Run the following cell to recreate the network with a smaller learning rate, `0.01`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That probably wasn't much different. Run the following cell to recreate the network one more time with an even smaller learning rate, `0.001`, and then train the new network.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.001)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# With a learning rate of `0.001`, the network should finally have started to improve during training. It's still not very good, but it shows that this solution has potential. We will improve it in the next lesson.

# %% [markdown]
# # End of Project 3.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Understanding Neural Noise<a id='lesson_4'></a>
#
# The following cells include includes the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
from IPython.display import Image
Image(filename='sentiment_network.png')

# %%
def update_input_layer(review):
    
    global layer_0
    
    # clear out previous state, reset the layer to be all 0s
    layer_0 *= 0
    for word in review.split(" "):
        layer_0[0][word2index[word]] += 1

update_input_layer(reviews[0])

# %%
layer_0

# %%
review_counter = Counter()

# %%
for word in reviews[0].split(" "):
    review_counter[word] += 1

# %%
review_counter.most_common()

# %% [markdown]
# # Project 4: Reducing Noise in Our Input Data<a id='project_4'></a>
#
# **TODO:** Attempt to reduce the noise in the input data like Andrew did in the previous video. Specifically, do the following:
# * Copy the `SentimentNetwork` class you created earlier into the following cell.
# * Modify `update_input_layer` so it does not count how many times each word is used, but rather just stores whether or not a word was used.

# %%
# TODO: -Copy the SentimentNetwork class from Projet 3 lesson
#       -Modify it to reduce noise, like in the video

# %% [markdown]
# Run the following cell to recreate the network and train it. Notice we've gone back to the higher learning rate of `0.1`.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. It's still not wonderful, but it should have improved dramatically. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 4.
# ## Andrew's solution was actually in the previous video, so rewatch that video if you had any problems with that project. Then continue on to the next lesson.
# # Analyzing Inefficiencies in our Network<a id='lesson_5'></a>
# The following cells include the code Andrew shows in the next video. We've included it here so you can run the cells along with the video without having to type in everything.

# %%
Image(filename='sentiment_network_sparse.png')

# %%
layer_0 = np.zeros(10)

# %%
layer_0

# %%
layer_0[4] = 1
layer_0[9] = 1

# %%
layer_0

# %%
weights_0_1 = np.random.randn(10,5)

# %%
layer_0.dot(weights_0_1)

# %%
indices = [4,9]

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (1 * weights_0_1[index])

# %%
layer_1

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
layer_1 = np.zeros(5)

# %%
for index in indices:
    layer_1 += (weights_0_1[index])

# %%
layer_1

# %% [markdown]
# # Project 5: Making our Network More Efficient<a id='project_5'></a>
# **TODO:** Make the `SentimentNetwork` class more efficient by eliminating unnecessary multiplications and additions that occur during forward and backward propagation. To do that, you can do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Remove the `update_input_layer` function - you will not need it in this version.
# * Modify `init_network`:
# >* You no longer need a separate input layer, so remove any mention of `self.layer_0`
# >* You will be dealing with the old hidden layer more directly, so create `self.layer_1`, a two-dimensional matrix with shape 1 x hidden_nodes, with all values initialized to zero
# * Modify `train`:
# >* Change the name of the input parameter `training_reviews` to `training_reviews_raw`. This will help with the next step.
# >* At the beginning of the function, you'll want to preprocess your reviews to convert them to a list of indices (from `word2index`) that are actually used in the review. This is equivalent to what you saw in the video when Andrew set specific indices to 1. Your code should create a local `list` variable named `training_reviews` that should contain a `list` for each review in `training_reviews_raw`. Those lists should contain the indices for words found in the review.
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* In the forward pass, replace the code that updates `layer_1` with new logic that only adds the weights for the indices used in the review.
# >* When updating `weights_0_1`, only update the individual weights that were used in the forward pass.
# * Modify `run`:
# >* Remove call to `update_input_layer`
# >* Use `self`'s  `layer_1` instead of a local `layer_1` object.
# >* Much like you did in `train`, you will need to pre-process the `review` so you can work with word indices, then update `layer_1` by adding weights for the indices used in the review.

# %%
# TODO: -Copy the SentimentNetwork class from Project 4 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to recreate the network and train it once again.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000], learning_rate=0.1)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# That should have trained much better than the earlier attempts. Run the following cell to test your model with 1000 predictions.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 5.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.
# # Further Noise Reduction<a id='lesson_6'></a>

# %%
Image(filename='sentiment_network_sparse_2.png')

# %%
# words most frequently seen in a review with a "POSITIVE" label
pos_neg_ratios.most_common()

# %%
# words most frequently seen in a review with a "NEGATIVE" label
list(reversed(pos_neg_ratios.most_common()))[0:30]

# %%
from bokeh.models import ColumnDataSource, LabelSet
from bokeh.plotting import figure, show, output_file
from bokeh.io import output_notebook
output_notebook()

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],pos_neg_ratios.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="Word Positive/Negative Affinity Distribution")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %%
frequency_frequency = Counter()

for word, cnt in total_counts.most_common():
    frequency_frequency[cnt] += 1

# %%
hist, edges = np.histogram(list(map(lambda x:x[1],frequency_frequency.most_common())), density=True, bins=100, normed=True)

p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="The frequency distribution of the words in our corpus")
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:], line_color="#555555")
show(p)

# %% [markdown]
# # Project 6: Reducing Noise by Strategically Reducing the Vocabulary<a id='project_6'></a>
#
# **TODO:** Improve `SentimentNetwork`'s performance by reducing more noise in the vocabulary. Specifically, do the following:
# * Copy the `SentimentNetwork` class from the previous project into the following cell.
# * Modify `pre_process_data`:
# >* Add two additional parameters: `min_count` and `polarity_cutoff`
# >* Calculate the positive-to-negative ratios of words used in the reviews. (You can use code you've written elsewhere in the notebook, but we are moving it into the class like we did with other helper code earlier.)
# >* Andrew's solution only calculates a postive-to-negative ratio for words that occur at least 50 times. This keeps the network from attributing too much sentiment to rarer words. You can choose to add this to your solution if you would like.
# >* Change so words are only added to the vocabulary if they occur in the vocabulary more than `min_count` times.
# >* Change so words are only added to the vocabulary if the absolute value of their postive-to-negative ratio is at least `polarity_cutoff`
# * Modify `__init__`:
# >* Add the same two parameters (`min_count` and `polarity_cutoff`) and use them when you call `pre_process_data`

# %%
# TODO: -Copy the SentimentNetwork class from Project 5 lesson
#       -Modify it according to the above instructions

# %% [markdown]
# Run the following cell to train your network with a small polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.05,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance. It should be

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# Run the following cell to train your network with a much larger polarity cutoff.

# %%
mlp = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=20,polarity_cutoff=0.8,learning_rate=0.01)
mlp.train(reviews[:-1000],labels[:-1000])

# %% [markdown]
# And run the following cell to test it's performance.

# %%
mlp.test(reviews[-1000:],labels[-1000:])

# %% [markdown]
# # End of Project 6.
# ## Watch the next video to see Andrew's solution, then continue on to the next lesson.

# %% [markdown]
# # Analysis: What's Going on in the Weights?<a id='lesson_7'></a>

# %%
mlp_full = SentimentNetwork(reviews[:-1000],labels[:-1000],min_count=0,polarity_cutoff=0,learning_rate=0.01)

# %%
mlp_full.train(reviews[:-1000],labels[:-1000])

# %%
Image(filename='sentiment_network_sparse.png')

# %%
def get_most_similar_words(focus = "horrible"):
    most_similar = Counter()

    for word in mlp_full.word2index.keys():
        most_similar[word] = np.dot(mlp_full.weights_0_1[mlp_full.word2index[word]],mlp_full.weights_0_1[mlp_full.word2index[focus]])
    
    return most_similar.most_common()

# %%
get_most_similar_words("excellent")

# %%
get_most_similar_words("terrible")

# %%
import matplotlib.colors as colors

words_to_visualize = list()
for word, ratio in pos_neg_ratios.most_common(500):
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)
    
for word, ratio in list(reversed(pos_neg_ratios.most_common()))[0:500]:
    if(word in mlp_full.word2index.keys()):
        words_to_visualize.append(word)

# %%
pos = 0
neg = 0

colors_list = list()
vectors_list = list()
for word in words_to_visualize:
    if word in pos_neg_ratios.keys():
        vectors_list.append(mlp_full.weights_0_1[mlp_full.word2index[word]])
        if(pos_neg_ratios[word] > 0):
            pos+=1
            colors_list.append("#00ff00")
        else:
            neg+=1
            colors_list.append("#000000")

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
words_top_ted_tsne = tsne.fit_transform(vectors_list)

# %%
p = figure(tools="pan,wheel_zoom,reset,save",
           toolbar_location="above",
           title="vector T-SNE for most polarized words")

source = ColumnDataSource(data=dict(x1=words_top_ted_tsne[:,0],
                                    x2=words_top_ted_tsne[:,1],
                                    names=words_to_visualize,
                                    color=colors_list))

p.scatter(x="x1", y="x2", size=8, source=source, fill_color="color")

word_labels = LabelSet(x="x1", y="x2", text="names", y_offset=6,
                  text_font_size="8pt", text_color="#555555",
                  source=source, text_align='center')
p.add_layout(word_labels)

show(p)

# green indicates positive words, black indicates negative words
